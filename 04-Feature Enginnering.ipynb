# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
def verify(df):
    print(df.shape)
    display(df.head())
    display(df.tail())

# %% [markdown]
# # Sales

# %%
df = pd.read_csv('data/train_clean.csv')
verify(df)
# Out:
# (3008016, 6)
#    index        date  store_nbr      family  sales  onpromotion
# 0      0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1      1  2013-01-02          1  AUTOMOTIVE    2.0            0
# 2      2  2013-01-03          1  AUTOMOTIVE    3.0            0
# 3      3  2013-01-04          1  AUTOMOTIVE    3.0            0
# 4      4  2013-01-05          1  AUTOMOTIVE    5.0            0
#            index        date  store_nbr   family      sales  onpromotion
# 3008011  3008011  2017-08-11          9  SEAFOOD  23.831000            0
# 3008012  3008012  2017-08-12          9  SEAFOOD  16.859001            4
# 3008013  3008013  2017-08-13          9  SEAFOOD  20.000000            0
# 3008014  3008014  2017-08-14          9  SEAFOOD  17.000000            0
# 3008015  3008015  2017-08-15          9  SEAFOOD  16.000000            0

# %%
df.drop(columns=['index'], inplace=True)
df['date'] = pd.to_datetime(df['date'])
df = df[df['date'] >= pd.to_datetime('2013-01-02')]

# %%
df['year'] = pd.to_datetime(df['date']).dt.year
df['month'] = pd.to_datetime(df['date']).dt.month
df['day'] = pd.to_datetime(df['date']).dt.day
df['day_of_week'] = pd.to_datetime(df['date']).dt.dayofweek
df['business_day'] = df['day_of_week'].apply(lambda x: 1 if x >= 5 else 0)

# %%
# def is_business_day(date):
#     return bool(len(pd.bdate_range(date, date)))

# df_dates = df[['date']].drop_duplicates()
# df_dates['business_day'] = df_dates['date'].apply(lambda x: is_business_day(x)).astype(int)

# df = df.merge(df_dates, on='date', how='inner')
df = df.sort_values(['store_nbr', 'family', 'date']).reset_index(drop=True)
verify(df)
# Out:
# (3006234, 10)
#         date  store_nbr      family  sales  onpromotion  year  month  day  \
# 0 2013-01-02          1  AUTOMOTIVE    2.0            0  2013      1    2
# 1 2013-01-03          1  AUTOMOTIVE    3.0            0  2013      1    3
# 2 2013-01-04          1  AUTOMOTIVE    3.0            0  2013      1    4
# 3 2013-01-05          1  AUTOMOTIVE    5.0            0  2013      1    5
# 4 2013-01-06          1  AUTOMOTIVE    2.0            0  2013      1    6
#
#    day_of_week  business_day
# 0            2             0
# 1            3             0
# 2            4             0
# 3            5             1
# 4            6             1
#               date  store_nbr   family  sales  onpromotion  year  month  day  \
# 3006229 2017-08-11         54  SEAFOOD    0.0            0  2017      8   11
# 3006230 2017-08-12         54  SEAFOOD    1.0            1  2017      8   12
# 3006231 2017-08-13         54  SEAFOOD    2.0            0  2017      8   13
# 3006232 2017-08-14         54  SEAFOOD    0.0            0  2017      8   14
# 3006233 2017-08-15         54  SEAFOOD    3.0            0  2017      8   15
#
#          day_of_week  business_day
# 3006229            4             0
# 3006230            5             1
# 3006231            6             1
# 3006232            0             0
# 3006233            1             0

# %%
cols_week = []
for lag in list(range(16,23)):
    df[f'sales_store_family_lag{lag}'] = df.groupby(['store_nbr', 'family']).sales.shift(lag)
    cols_week.append(f'sales_store_family_lag{lag}')

cols_year = []
for lag in list(range(30,361,30)):
    df[f'sales_store_family_lag{lag}'] = df.groupby(['store_nbr', 'family']).sales.shift(lag)
    cols_year.append(f'sales_store_family_lag{lag}')
    
df['ema_sales_store_family_week'] = df.groupby(['store_nbr', 'family']).sales.ewm(span=7, adjust=False, min_periods=7).mean().reset_index(drop=True)
df['ema_sales_store_family_lag_16_22'] = df.groupby(['store_nbr', 'family']).ema_sales_store_family_week.shift(16)

df['ema_sales_store_family_month'] = df.groupby(['store_nbr', 'family']).sales.rolling(30, min_periods=30).mean().reset_index(drop=True)
df['ema_sales_store_family_lag_16_45'] = df.groupby(['store_nbr', 'family']).ema_sales_store_family_month.shift(16)

df['ema_sales_store_family_year'] = df.groupby(['store_nbr', 'family']).sales.rolling(365, min_periods=365).mean().reset_index(drop=True)
df['ema_sales_store_family_lag_16_380'] = df.groupby(['store_nbr', 'family']).ema_sales_store_family_year.shift(16)

df.drop(columns=['ema_sales_store_family_week', 'ema_sales_store_family_month', 'ema_sales_store_family_year'], 
        inplace=True)

verify(df)
print(df[[i for i in df.columns if 'sales_store_family_lag' in i]].isna().sum())
# Out:
# (3006234, 32)
#         date  store_nbr      family  sales  onpromotion  year  month  day  \
# 0 2013-01-02          1  AUTOMOTIVE    2.0            0  2013      1    2
# 1 2013-01-03          1  AUTOMOTIVE    3.0            0  2013      1    3
# 2 2013-01-04          1  AUTOMOTIVE    3.0            0  2013      1    4
# 3 2013-01-05          1  AUTOMOTIVE    5.0            0  2013      1    5
# 4 2013-01-06          1  AUTOMOTIVE    2.0            0  2013      1    6
#
#    day_of_week  business_day  sales_store_family_lag16  \
# 0            2             0                       NaN
# 1            3             0                       NaN
# 2            4             0                       NaN
# 3            5             1                       NaN
# 4            6             1                       NaN
#
#    sales_store_family_lag17  sales_store_family_lag18  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    sales_store_family_lag19  sales_store_family_lag20  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    sales_store_family_lag21  sales_store_family_lag22  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    sales_store_family_lag30  sales_store_family_lag60  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    sales_store_family_lag90  sales_store_family_lag120  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#    sales_store_family_lag150  sales_store_family_lag180  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    sales_store_family_lag210  sales_store_family_lag240  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    sales_store_family_lag270  sales_store_family_lag300  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    sales_store_family_lag330  sales_store_family_lag360  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    ema_sales_store_family_lag_16_22  ema_sales_store_family_lag_16_45  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#    ema_sales_store_family_lag_16_380
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#               date  store_nbr   family  sales  onpromotion  year  month  day  \
# 3006229 2017-08-11         54  SEAFOOD    0.0            0  2017      8   11
# 3006230 2017-08-12         54  SEAFOOD    1.0            1  2017      8   12
# 3006231 2017-08-13         54  SEAFOOD    2.0            0  2017      8   13
# 3006232 2017-08-14         54  SEAFOOD    0.0            0  2017      8   14
# 3006233 2017-08-15         54  SEAFOOD    3.0            0  2017      8   15
#
#          day_of_week  business_day  sales_store_family_lag16  \
# 3006229            4             0                       3.0
# 3006230            5             1                       2.0
# 3006231            6             1                       4.0
# 3006232            0             0                       4.0
# 3006233            1             0                       4.0
#
#          sales_store_family_lag17  sales_store_family_lag18  \
# 3006229                       7.0                       1.0
# 3006230                       3.0                       7.0
# 3006231                       2.0                       3.0
# 3006232                       4.0                       2.0
# 3006233                       4.0                       4.0
#
#          sales_store_family_lag19  sales_store_family_lag20  \
# 3006229                       5.0                       3.0
# 3006230                       1.0                       5.0
# 3006231                       7.0                       1.0
# 3006232                       3.0                       7.0
# 3006233                       2.0                       3.0
#
#          sales_store_family_lag21  sales_store_family_lag22  \
# 3006229                       0.0                       3.0
# 3006230                       3.0                       0.0
# 3006231                       5.0                       3.0
# 3006232                       1.0                       5.0
# 3006233                       7.0                       1.0
#
#          sales_store_family_lag30  sales_store_family_lag60  \
# 3006229                       1.0                       5.0
# 3006230                       0.0                       0.0
# 3006231                       0.0                       3.0
# 3006232                       2.0                       0.0
# 3006233                       5.0                       2.0
#
#          sales_store_family_lag90  sales_store_family_lag120  \
# 3006229                       4.0                        1.0
# 3006230                       9.0                        6.0
# 3006231                       9.0                        0.0
# 3006232                       4.0                        2.0
# 3006233                       2.0                        0.0
#
#          sales_store_family_lag150  sales_store_family_lag180  \
# 3006229                        2.0                        2.0
# 3006230                        8.0                        0.0
# 3006231                        1.0                        0.0
# 3006232                        0.0                        4.0
# 3006233                        3.0                        1.0
#
#          sales_store_family_lag210  sales_store_family_lag240  \
# 3006229                        2.0                        1.0
# 3006230                        1.0                        1.0
# 3006231                        2.0                        2.0
# 3006232                        2.0                        1.0
# 3006233                        2.0                        5.0
#
#          sales_store_family_lag270  sales_store_family_lag300  \
# 3006229                        7.0                        1.0
# 3006230                        4.0                        0.0
# 3006231                        2.0                        3.0
# 3006232                        1.0                        2.0
# 3006233                        0.0                        0.0
#
#          sales_store_family_lag330  sales_store_family_lag360  \
# 3006229                        0.0                        5.0
# 3006230                        2.0                        1.0
# 3006231                        2.0                        2.0
# 3006232                        0.0                        0.0
# 3006233                        0.0                        2.0
#
#          ema_sales_store_family_lag_16_22  ema_sales_store_family_lag_16_45  \
# 3006229                          3.470481                          3.066667
# 3006230                          3.102860                          2.766667
# 3006231                          3.327145                          2.866667
# 3006232                          3.495359                          2.966667
# 3006233                          3.621519                          3.100000
#
#          ema_sales_store_family_lag_16_380
# 3006229                           1.934247
# 3006230                           1.939726
# 3006231                           1.945205
# 3006232                           1.956164
# 3006233                           1.967123
# sales_store_family_lag16              28512
# sales_store_family_lag17              30294
# sales_store_family_lag18              32076
# sales_store_family_lag19              33858
# sales_store_family_lag20              35640
# sales_store_family_lag21              37422
# sales_store_family_lag22              39204
# sales_store_family_lag30              53460
# sales_store_family_lag60             106920
# sales_store_family_lag90             160380
# sales_store_family_lag120            213840
# sales_store_family_lag150            267300
# sales_store_family_lag180            320760
# sales_store_family_lag210            374220
# sales_store_family_lag240            427680
# sales_store_family_lag270            481140
# sales_store_family_lag300            534600
# sales_store_family_lag330            588060
# sales_store_family_lag360            641520
# ema_sales_store_family_lag_16_22      39204
# ema_sales_store_family_lag_16_45      80190
# ema_sales_store_family_lag_16_380    677160
# dtype: int64

# %%
df_stores = df.groupby(['date', 'store_nbr']).sales.sum().reset_index()
df_stores = df_stores.sort_values(['store_nbr', 'date']).reset_index(drop=True)

cols_week = []
for lag in list(range(16,23)):
    df_stores[f'sales_store_lag{lag}'] = df_stores.groupby(['store_nbr']).sales.shift(lag)
    cols_week.append(f'sales_store_lag{lag}')
    
cols_year = []
for lag in list(range(30,361,30)):
    df_stores[f'sales_store_lag{lag}'] = df_stores.groupby(['store_nbr']).sales.shift(lag)
    cols_year.append(f'sales_store_lag{lag}')

df_stores['ema_sales_store_week'] = df_stores.groupby(['store_nbr']).sales.ewm(span=7, adjust=False, min_periods=7).mean().reset_index(drop=True)
df_stores['ema_sales_store_lag_16_22'] = df_stores.groupby(['store_nbr']).ema_sales_store_week.shift(16)

df_stores['ema_sales_store_month'] = df_stores.groupby(['store_nbr']).sales.rolling(30, min_periods=30).mean().reset_index(drop=True)
df_stores['ema_sales_store_lag_16_45'] = df_stores.groupby(['store_nbr']).ema_sales_store_month.shift(16)

df_stores['ema_sales_store_year'] = df_stores.groupby(['store_nbr']).sales.rolling(365, min_periods=365).mean().reset_index(drop=True)
df_stores['ema_sales_store_lag_16_380'] = df_stores.groupby(['store_nbr']).ema_sales_store_year.shift(16)

df_stores.drop(columns=['ema_sales_store_week', 'ema_sales_store_month', 'ema_sales_store_year', 'sales'], 
        inplace=True)

verify(df_stores)
print(df_stores[[i for i in df_stores.columns if 'sales_store_lag' in i]].isna().sum())
# Out:
# (91098, 24)
#         date  store_nbr  sales_store_lag16  sales_store_lag17  \
# 0 2013-01-02          1                NaN                NaN
# 1 2013-01-03          1                NaN                NaN
# 2 2013-01-04          1                NaN                NaN
# 3 2013-01-05          1                NaN                NaN
# 4 2013-01-06          1                NaN                NaN
#
#    sales_store_lag18  sales_store_lag19  sales_store_lag20  sales_store_lag21  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#    sales_store_lag22  sales_store_lag30  sales_store_lag60  sales_store_lag90  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#    sales_store_lag120  sales_store_lag150  sales_store_lag180  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    sales_store_lag210  sales_store_lag240  sales_store_lag270  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    sales_store_lag300  sales_store_lag330  sales_store_lag360  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    ema_sales_store_lag_16_22  ema_sales_store_lag_16_45  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    ema_sales_store_lag_16_380
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#             date  store_nbr  sales_store_lag16  sales_store_lag17  \
# 91093 2017-08-11         54        6572.494000        8241.906000
# 91094 2017-08-12         54        6911.345000        6572.494000
# 91095 2017-08-13         54        9531.089998        6911.345000
# 91096 2017-08-14         54       10878.746000        9531.089998
# 91097 2017-08-15         54       15815.709996       10878.746000
#
#        sales_store_lag18  sales_store_lag19  sales_store_lag20  \
# 91093       10245.246998       16841.417000        9739.265000
# 91094        8241.906000       10245.246998       16841.417000
# 91095        6572.494000        8241.906000       10245.246998
# 91096        6911.345000        6572.494000        8241.906000
# 91097        9531.089998        6911.345000        6572.494000
#
#        sales_store_lag21  sales_store_lag22  sales_store_lag30  \
# 91093       10845.986000        7097.149003        8042.298000
# 91094        9739.265000       10845.986000        6722.425000
# 91095       16841.417000        9739.265000        6765.057998
# 91096       10245.246998       16841.417000        9306.720000
# 91097        8241.906000       10245.246998       16959.135000
#
#        sales_store_lag60  sales_store_lag90  sales_store_lag120  \
# 91093       11821.521000          11318.824         7956.353002
# 91094        9262.571000          11251.186         6093.959000
# 91095        9678.241998          13391.214         8845.043000
# 91096        6506.621000           9195.975        10599.092000
# 91097       10540.249999          17721.085         8402.924000
#
#        sales_store_lag150  sales_store_lag180  sales_store_lag210  \
# 91093         8192.171000        11721.063000            7262.782
# 91094         7520.890000         8257.622000            8834.506
# 91095         5348.335998         6807.944000           11633.912
# 91096         7928.360000         7077.091998            9775.383
# 91097        10604.055000         5518.609000            7374.671
#
#        sales_store_lag240  sales_store_lag270  sales_store_lag300  \
# 91093         6872.459002        10855.031002            8966.580
# 91094         6923.343000         9892.957000           13494.297
# 91095         8206.350995         7604.733000            8572.510
# 91096         9473.449002         9304.739002            8637.075
# 91097        12540.281000         5940.149002            6340.114
#
#        sales_store_lag330  sales_store_lag360  ema_sales_store_lag_16_22  \
# 91093         6323.353000         7951.739006                9412.730787
# 91094         6812.701002         6246.614000                8787.384341
# 91095         8997.745000         6128.879997                8973.310755
# 91096        12835.125000         6315.900000                9449.669566
# 91097         8185.356998         8424.711000               11041.179674
#
#        ema_sales_store_lag_16_45  ema_sales_store_lag_16_380
# 91093                9832.126766                 8773.782915
# 91094                9776.435700                 8776.847039
# 91095                9865.920500                 8789.411924
# 91096                9927.366300                 8801.114677
# 91097               10163.706700                 8816.963789
# sales_store_lag16               864
# sales_store_lag17               918
# sales_store_lag18               972
# sales_store_lag19              1026
# sales_store_lag20              1080
# sales_store_lag21              1134
# sales_store_lag22              1188
# sales_store_lag30              1620
# sales_store_lag60              3240
# sales_store_lag90              4860
# sales_store_lag120             6480
# sales_store_lag150             8100
# sales_store_lag180             9720
# sales_store_lag210            11340
# sales_store_lag240            12960
# sales_store_lag270            14580
# sales_store_lag300            16200
# sales_store_lag330            17820
# sales_store_lag360            19440
# ema_sales_store_lag_16_22      1188
# ema_sales_store_lag_16_45      2430
# ema_sales_store_lag_16_380    20520
# dtype: int64

# %%
df_families = df.groupby(['date', 'family']).sales.sum().reset_index()
df_families = df_families.sort_values(['family', 'date']).reset_index(drop=True)

cols_week = []
for lag in list(range(16,23)):
    df_families[f'sales_family_lag{lag}'] = df_families.groupby(['family']).sales.shift(lag)
    cols_week.append(f'sales_family_lag{lag}')

cols_year = []
for lag in list(range(30,361,30)):
    df_families[f'sales_family_lag{lag}'] = df_families.groupby(['family']).sales.shift(lag)
    cols_year.append(f'sales_family_lag{lag}')

df_families['ema_sales_family_week'] = df_families.groupby(['family']).sales.ewm(span=7, adjust=False, min_periods=7).mean().reset_index(drop=True)
df_families['ema_sales_family_lag_16_22'] = df_families.groupby(['family']).ema_sales_family_week.shift(16)

df_families['ema_sales_family_month'] = df_families.groupby(['family']).sales.rolling(30, min_periods=30).mean().reset_index(drop=True)
df_families['ema_sales_family_lag_16_45'] = df_families.groupby(['family']).ema_sales_family_month.shift(16)

df_families['ema_sales_family_year'] = df_families.groupby(['family']).sales.rolling(365, min_periods=365).mean().reset_index(drop=True)
df_families['ema_sales_family_lag_16_380'] = df_families.groupby(['family']).ema_sales_family_year.shift(16)

df_families.drop(columns=['ema_sales_family_week', 'ema_sales_family_month', 'ema_sales_family_year', 'sales'], 
        inplace=True)

verify(df_families)
print(df_families[[i for i in df_families.columns if 'sales_family_lag' in i]].isna().sum())
# Out:
# (55671, 24)
#         date      family  sales_family_lag16  sales_family_lag17  \
# 0 2013-01-02  AUTOMOTIVE                 NaN                 NaN
# 1 2013-01-03  AUTOMOTIVE                 NaN                 NaN
# 2 2013-01-04  AUTOMOTIVE                 NaN                 NaN
# 3 2013-01-05  AUTOMOTIVE                 NaN                 NaN
# 4 2013-01-06  AUTOMOTIVE                 NaN                 NaN
#
#    sales_family_lag18  sales_family_lag19  sales_family_lag20  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    sales_family_lag21  sales_family_lag22  sales_family_lag30  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    sales_family_lag60  sales_family_lag90  sales_family_lag120  \
# 0                 NaN                 NaN                  NaN
# 1                 NaN                 NaN                  NaN
# 2                 NaN                 NaN                  NaN
# 3                 NaN                 NaN                  NaN
# 4                 NaN                 NaN                  NaN
#
#    sales_family_lag150  sales_family_lag180  sales_family_lag210  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    sales_family_lag240  sales_family_lag270  sales_family_lag300  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    sales_family_lag330  sales_family_lag360  ema_sales_family_lag_16_22  \
# 0                  NaN                  NaN                         NaN
# 1                  NaN                  NaN                         NaN
# 2                  NaN                  NaN                         NaN
# 3                  NaN                  NaN                         NaN
# 4                  NaN                  NaN                         NaN
#
#    ema_sales_family_lag_16_45  ema_sales_family_lag_16_380
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#             date   family  sales_family_lag16  sales_family_lag17  \
# 55666 2017-08-11  SEAFOOD          839.655002          842.090999
# 55667 2017-08-12  SEAFOOD          652.069999          839.655002
# 55668 2017-08-13  SEAFOOD         1307.945999          652.069999
# 55669 2017-08-14  SEAFOOD         1297.514006         1307.945999
# 55670 2017-08-15  SEAFOOD         1379.617003         1297.514006
#
#        sales_family_lag18  sales_family_lag19  sales_family_lag20  \
# 55666          995.327001         1336.117001         1237.136004
# 55667          842.090999          995.327001         1336.117001
# 55668          839.655002          842.090999          995.327001
# 55669          652.069999          839.655002          842.090999
# 55670         1307.945999          652.069999          839.655002
#
#        sales_family_lag21  sales_family_lag22  sales_family_lag30  \
# 55666         1279.617002          832.490001          910.025003
# 55667         1237.136004         1279.617002          763.185000
# 55668         1336.117001         1237.136004         1168.711002
# 55669          995.327001         1336.117001         1116.871994
# 55670          842.090999          995.327001         1413.877000
#
#        sales_family_lag60  sales_family_lag90  sales_family_lag120  \
# 55666          733.046999         1586.752001          1338.790996
# 55667          731.403995         1109.968000          1663.270998
# 55668          853.077994         1176.515991          1219.864000
# 55669          677.453000         1207.565999          1380.766001
# 55670         1315.639001         1195.405000           998.932001
#
#        sales_family_lag150  sales_family_lag180  sales_family_lag210  \
# 55666          1122.169993          1549.751998          1499.210012
# 55667          1316.079002          1092.972998          1449.434000
# 55668          1143.293005           889.708000          1597.529992
# 55669          1855.046000           981.652003          1101.452004
# 55670          1597.305998           858.070005           990.695003
#
#        sales_family_lag240  sales_family_lag270  sales_family_lag300  \
# 55666          1000.610003          1168.591997          1412.043001
# 55667           668.240001          1081.247003          1833.255003
# 55668          1297.765000          1279.605003          1152.918007
# 55669          1157.602995           787.699001          1006.996007
# 55670          1289.671995          1362.009002          1080.609002
#
#        sales_family_lag330  sales_family_lag360  ema_sales_family_lag_16_22  \
# 55666           914.278999          1231.333995                  994.971666
# 55667          1648.302995          1272.509000                  909.246249
# 55668          1526.577002          1005.604001                 1008.921187
# 55669          1624.924003          1577.567993                 1081.069392
# 55670          1138.018999          1447.197998                 1155.706294
#
#        ema_sales_family_lag_16_45  ema_sales_family_lag_16_380
# 55666                 1106.508366                  1214.055734
# 55667                 1097.978233                  1213.060436
# 55668                 1110.908100                  1214.387918
# 55669                 1130.908133                  1213.776773
# 55670                 1131.143900                  1213.799340
# sales_family_lag16               528
# sales_family_lag17               561
# sales_family_lag18               594
# sales_family_lag19               627
# sales_family_lag20               660
# sales_family_lag21               693
# sales_family_lag22               726
# sales_family_lag30               990
# sales_family_lag60              1980
# sales_family_lag90              2970
# sales_family_lag120             3960
# sales_family_lag150             4950
# sales_family_lag180             5940
# sales_family_lag210             6930
# sales_family_lag240             7920
# sales_family_lag270             8910
# sales_family_lag300             9900
# sales_family_lag330            10890
# sales_family_lag360            11880
# ema_sales_family_lag_16_22       726
# ema_sales_family_lag_16_45      1485
# ema_sales_family_lag_16_380    12540
# dtype: int64

# %%
df.merge(df_stores, on=['date', 'store_nbr'], how='inner')
# Out:
#               date  store_nbr                      family     sales  \
# 0       2013-01-02          1                  AUTOMOTIVE     2.000
# 1       2013-01-02          1                   BABY CARE     0.000
# 2       2013-01-02          1                      BEAUTY     2.000
# 3       2013-01-02          1                   BEVERAGES  1091.000
# 4       2013-01-02          1                       BOOKS     0.000
# ...            ...        ...                         ...       ...
# 3006229 2017-08-15         54                     POULTRY    59.619
# 3006230 2017-08-15         54              PREPARED FOODS    94.000
# 3006231 2017-08-15         54                     PRODUCE   915.371
# 3006232 2017-08-15         54  SCHOOL AND OFFICE SUPPLIES     0.000
# 3006233 2017-08-15         54                     SEAFOOD     3.000
#
#          onpromotion  year  month  day  day_of_week  business_day  \
# 0                  0  2013      1    2            2             0
# 1                  0  2013      1    2            2             0
# 2                  0  2013      1    2            2             0
# 3                  0  2013      1    2            2             0
# 4                  0  2013      1    2            2             0
# ...              ...   ...    ...  ...          ...           ...
# 3006229            0  2017      8   15            1             0
# 3006230            0  2017      8   15            1             0
# 3006231           76  2017      8   15            1             0
# 3006232            0  2017      8   15            1             0
# 3006233            0  2017      8   15            1             0
#
#          sales_store_family_lag16  sales_store_family_lag17  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
# ...                           ...                       ...
# 3006229                 72.895996                    82.296
# 3006230                124.000000                    81.000
# 3006231                793.147000                   729.844
# 3006232                  0.000000                     0.000
# 3006233                  4.000000                     4.000
#
#          sales_store_family_lag18  sales_store_family_lag19  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
# ...                           ...                       ...
# 3006229                    46.656                    52.086
# 3006230                    68.000                    73.000
# 3006231                   562.097                   520.489
# 3006232                     0.000                     0.000
# 3006233                     4.000                     2.000
#
#          sales_store_family_lag20  sales_store_family_lag21  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
# ...                           ...                       ...
# 3006229                    34.856                    50.686
# 3006230                    81.000                    65.000
# 3006231                   559.658                   914.959
# 3006232                     0.000                     0.000
# 3006233                     3.000                     7.000
#
#          sales_store_family_lag22  sales_store_family_lag30  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
# ...                           ...                       ...
# 3006229                    51.209                   103.902
# 3006230                   112.000                    50.000
# 3006231                   654.930                   981.712
# 3006232                     0.000                     0.000
# 3006233                     1.000                     5.000
#
#          sales_store_family_lag60  sales_store_family_lag90  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
# ...                           ...                       ...
# 3006229                    72.770                    44.233
# 3006230                    79.000                    81.000
# 3006231                   580.389                   506.987
# 3006232                     0.000                     1.000
# 3006233                     2.000                     2.000
#
#          sales_store_family_lag120  sales_store_family_lag150  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                              NaN                        NaN
# ...                            ...                        ...
# 3006229                     56.169                     47.291
# 3006230                     29.000                     70.000
# 3006231                    559.538                    659.408
# 3006232                      1.000                      0.000
# 3006233                      0.000                      3.000
#
#          sales_store_family_lag180  sales_store_family_lag210  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                              NaN                        NaN
# ...                            ...                        ...
# 3006229                     46.572                     57.161
# 3006230                     49.000                     98.000
# 3006231                    426.046                    862.417
# 3006232                      0.000                      0.000
# 3006233                      1.000                      2.000
#
#          sales_store_family_lag240  sales_store_family_lag270  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                              NaN                        NaN
# ...                            ...                        ...
# 3006229                     66.212                     91.916
# 3006230                    103.000                     74.000
# 3006231                    816.129                    613.487
# 3006232                      0.000                      0.000
# 3006233                      5.000                      0.000
#
#          sales_store_family_lag300  sales_store_family_lag330  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                              NaN                        NaN
# ...                            ...                        ...
# 3006229                     34.801                  49.364998
# 3006230                     70.000                  80.000000
# 3006231                    555.718                 549.655000
# 3006232                      0.000                   0.000000
# 3006233                      0.000                   0.000000
#
#          sales_store_family_lag360  ema_sales_store_family_lag_16_22  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
# ...                            ...                               ...
# 3006229                     29.669                      6.453319e+01
# 3006230                     52.000                      9.153548e+01
# 3006231                    713.194                      6.889917e+02
# 3006232                      0.000                      2.320649e-09
# 3006233                      2.000                      3.621519e+00
#
#          ema_sales_store_family_lag_16_45  ema_sales_store_family_lag_16_380  \
# 0                                     NaN                                NaN
# 1                                     NaN                                NaN
# 2                                     NaN                                NaN
# 3                                     NaN                                NaN
# 4                                     NaN                                NaN
# ...                                   ...                                ...
# 3006229                         69.364066                          62.222482
# 3006230                         85.000000                          75.816438
# 3006231                        698.255533                         655.923181
# 3006232                          0.000000                           1.679452
# 3006233                          3.100000                           1.967123
#
#          sales_store_lag16  sales_store_lag17  sales_store_lag18  \
# 0                      NaN                NaN                NaN
# 1                      NaN                NaN                NaN
# 2                      NaN                NaN                NaN
# 3                      NaN                NaN                NaN
# 4                      NaN                NaN                NaN
# ...                    ...                ...                ...
# 3006229       15815.709996          10878.746        9531.089998
# 3006230       15815.709996          10878.746        9531.089998
# 3006231       15815.709996          10878.746        9531.089998
# 3006232       15815.709996          10878.746        9531.089998
# 3006233       15815.709996          10878.746        9531.089998
#
#          sales_store_lag19  sales_store_lag20  sales_store_lag21  \
# 0                      NaN                NaN                NaN
# 1                      NaN                NaN                NaN
# 2                      NaN                NaN                NaN
# 3                      NaN                NaN                NaN
# 4                      NaN                NaN                NaN
# ...                    ...                ...                ...
# 3006229           6911.345           6572.494           8241.906
# 3006230           6911.345           6572.494           8241.906
# 3006231           6911.345           6572.494           8241.906
# 3006232           6911.345           6572.494           8241.906
# 3006233           6911.345           6572.494           8241.906
#
#          sales_store_lag22  sales_store_lag30  sales_store_lag60  \
# 0                      NaN                NaN                NaN
# 1                      NaN                NaN                NaN
# 2                      NaN                NaN                NaN
# 3                      NaN                NaN                NaN
# 4                      NaN                NaN                NaN
# ...                    ...                ...                ...
# 3006229       10245.246998          16959.135       10540.249999
# 3006230       10245.246998          16959.135       10540.249999
# 3006231       10245.246998          16959.135       10540.249999
# 3006232       10245.246998          16959.135       10540.249999
# 3006233       10245.246998          16959.135       10540.249999
#
#          sales_store_lag90  sales_store_lag120  sales_store_lag150  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 3006229          17721.085            8402.924           10604.055
# 3006230          17721.085            8402.924           10604.055
# 3006231          17721.085            8402.924           10604.055
# 3006232          17721.085            8402.924           10604.055
# 3006233          17721.085            8402.924           10604.055
#
#          sales_store_lag180  sales_store_lag210  sales_store_lag240  \
# 0                       NaN                 NaN                 NaN
# 1                       NaN                 NaN                 NaN
# 2                       NaN                 NaN                 NaN
# 3                       NaN                 NaN                 NaN
# 4                       NaN                 NaN                 NaN
# ...                     ...                 ...                 ...
# 3006229            5518.609            7374.671           12540.281
# 3006230            5518.609            7374.671           12540.281
# 3006231            5518.609            7374.671           12540.281
# 3006232            5518.609            7374.671           12540.281
# 3006233            5518.609            7374.671           12540.281
#
#          sales_store_lag270  sales_store_lag300  sales_store_lag330  \
# 0                       NaN                 NaN                 NaN
# 1                       NaN                 NaN                 NaN
# 2                       NaN                 NaN                 NaN
# 3                       NaN                 NaN                 NaN
# 4                       NaN                 NaN                 NaN
# ...                     ...                 ...                 ...
# 3006229         5940.149002            6340.114         8185.356998
# 3006230         5940.149002            6340.114         8185.356998
# 3006231         5940.149002            6340.114         8185.356998
# 3006232         5940.149002            6340.114         8185.356998
# 3006233         5940.149002            6340.114         8185.356998
#
#          sales_store_lag360  ema_sales_store_lag_16_22  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
# ...                     ...                        ...
# 3006229            8424.711               11041.179674
# 3006230            8424.711               11041.179674
# 3006231            8424.711               11041.179674
# 3006232            8424.711               11041.179674
# 3006233            8424.711               11041.179674
#
#          ema_sales_store_lag_16_45  ema_sales_store_lag_16_380
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 3006229                 10163.7067                 8816.963789
# 3006230                 10163.7067                 8816.963789
# 3006231                 10163.7067                 8816.963789
# 3006232                 10163.7067                 8816.963789
# 3006233                 10163.7067                 8816.963789
#
# [3006234 rows x 54 columns]

# %%
df = df.dropna(how='any')
verify(df)

df_stores = df_stores.dropna(how='any')
verify(df_stores)

df_families = df_families.dropna(how='any')
verify(df_families)
# Out:
# (2329074, 32)
#           date  store_nbr      family  sales  onpromotion  year  month  day  \
# 380 2014-01-17          1  AUTOMOTIVE    2.0            0  2014      1   17
# 381 2014-01-18          1  AUTOMOTIVE    4.0            0  2014      1   18
# 382 2014-01-19          1  AUTOMOTIVE    0.0            0  2014      1   19
# 383 2014-01-20          1  AUTOMOTIVE    2.0            0  2014      1   20
# 384 2014-01-21          1  AUTOMOTIVE    9.0            0  2014      1   21
#
#      day_of_week  business_day  sales_store_family_lag16  \
# 380            4             0                       0.0
# 381            5             1                       3.0
# 382            6             1                       0.0
# 383            0             0                       0.0
# 384            1             0                       1.0
#
#      sales_store_family_lag17  sales_store_family_lag18  \
# 380                       2.0                       1.0
# 381                       0.0                       2.0
# 382                       3.0                       0.0
# 383                       0.0                       3.0
# 384                       0.0                       0.0
#
#      sales_store_family_lag19  sales_store_family_lag20  \
# 380                       0.0                       4.0
# 381                       1.0                       0.0
# 382                       2.0                       1.0
# 383                       0.0                       2.0
# 384                       3.0                       0.0
#
#      sales_store_family_lag21  sales_store_family_lag22  \
# 380                       6.0                       2.0
# 381                       4.0                       6.0
# 382                       0.0                       4.0
# 383                       1.0                       0.0
# 384                       2.0                       1.0
#
#      sales_store_family_lag30  sales_store_family_lag60  \
# 380                       1.0                       1.0
# 381                       0.0                       4.0
# 382                       5.0                       6.0
# 383                       5.0                       3.0
# 384                       0.0                       2.0
#
#      sales_store_family_lag90  sales_store_family_lag120  \
# 380                       1.0                        2.0
# 381                       1.0                        5.0
# 382                       1.0                        2.0
# 383                       7.0                        1.0
# 384                       1.0                        1.0
#
#      sales_store_family_lag150  sales_store_family_lag180  \
# 380                        1.0                        1.0
# 381                        4.0                        2.0
# 382                        4.0                        3.0
# 383                        2.0                        7.0
# 384                        2.0                        1.0
#
#      sales_store_family_lag210  sales_store_family_lag240  \
# 380                        5.0                        1.0
# 381                        4.0                        6.0
# 382                        3.0                        2.0
# 383                        1.0                        1.0
# 384                        2.0                        2.0
#
#      sales_store_family_lag270  sales_store_family_lag300  \
# 380                        2.0                        0.0
# 381                        5.0                        1.0
# 382                        3.0                        4.0
# 383                        2.0                       10.0
# 384                        3.0                        3.0
#
#      sales_store_family_lag330  sales_store_family_lag360  \
# 380                        1.0                        1.0
# 381                        2.0                        3.0
# 382                        4.0                        0.0
# 383                        0.0                        5.0
# 384                        1.0                        4.0
#
#      ema_sales_store_family_lag_16_22  ema_sales_store_family_lag_16_45  \
# 380                          1.474098                          1.833333
# 381                          1.855573                          1.866667
# 382                          1.391680                          1.833333
# 383                          1.043760                          1.833333
# 384                          1.032820                          1.800000
#
#      ema_sales_store_family_lag_16_380
# 380                           2.142466
# 381                           2.145205
# 382                           2.136986
# 383                           2.128767
# 384                           2.117808
#               date  store_nbr   family  sales  onpromotion  year  month  day  \
# 3006229 2017-08-11         54  SEAFOOD    0.0            0  2017      8   11
# 3006230 2017-08-12         54  SEAFOOD    1.0            1  2017      8   12
# 3006231 2017-08-13         54  SEAFOOD    2.0            0  2017      8   13
# 3006232 2017-08-14         54  SEAFOOD    0.0            0  2017      8   14
# 3006233 2017-08-15         54  SEAFOOD    3.0            0  2017      8   15
#
#          day_of_week  business_day  sales_store_family_lag16  \
# 3006229            4             0                       3.0
# 3006230            5             1                       2.0
# 3006231            6             1                       4.0
# 3006232            0             0                       4.0
# 3006233            1             0                       4.0
#
#          sales_store_family_lag17  sales_store_family_lag18  \
# 3006229                       7.0                       1.0
# 3006230                       3.0                       7.0
# 3006231                       2.0                       3.0
# 3006232                       4.0                       2.0
# 3006233                       4.0                       4.0
#
#          sales_store_family_lag19  sales_store_family_lag20  \
# 3006229                       5.0                       3.0
# 3006230                       1.0                       5.0
# 3006231                       7.0                       1.0
# 3006232                       3.0                       7.0
# 3006233                       2.0                       3.0
#
#          sales_store_family_lag21  sales_store_family_lag22  \
# 3006229                       0.0                       3.0
# 3006230                       3.0                       0.0
# 3006231                       5.0                       3.0
# 3006232                       1.0                       5.0
# 3006233                       7.0                       1.0
#
#          sales_store_family_lag30  sales_store_family_lag60  \
# 3006229                       1.0                       5.0
# 3006230                       0.0                       0.0
# 3006231                       0.0                       3.0
# 3006232                       2.0                       0.0
# 3006233                       5.0                       2.0
#
#          sales_store_family_lag90  sales_store_family_lag120  \
# 3006229                       4.0                        1.0
# 3006230                       9.0                        6.0
# 3006231                       9.0                        0.0
# 3006232                       4.0                        2.0
# 3006233                       2.0                        0.0
#
#          sales_store_family_lag150  sales_store_family_lag180  \
# 3006229                        2.0                        2.0
# 3006230                        8.0                        0.0
# 3006231                        1.0                        0.0
# 3006232                        0.0                        4.0
# 3006233                        3.0                        1.0
#
#          sales_store_family_lag210  sales_store_family_lag240  \
# 3006229                        2.0                        1.0
# 3006230                        1.0                        1.0
# 3006231                        2.0                        2.0
# 3006232                        2.0                        1.0
# 3006233                        2.0                        5.0
#
#          sales_store_family_lag270  sales_store_family_lag300  \
# 3006229                        7.0                        1.0
# 3006230                        4.0                        0.0
# 3006231                        2.0                        3.0
# 3006232                        1.0                        2.0
# 3006233                        0.0                        0.0
#
#          sales_store_family_lag330  sales_store_family_lag360  \
# 3006229                        0.0                        5.0
# 3006230                        2.0                        1.0
# 3006231                        2.0                        2.0
# 3006232                        0.0                        0.0
# 3006233                        0.0                        2.0
#
#          ema_sales_store_family_lag_16_22  ema_sales_store_family_lag_16_45  \
# 3006229                          3.470481                          3.066667
# 3006230                          3.102860                          2.766667
# 3006231                          3.327145                          2.866667
# 3006232                          3.495359                          2.966667
# 3006233                          3.621519                          3.100000
#
#          ema_sales_store_family_lag_16_380
# 3006229                           1.934247
# 3006230                           1.939726
# 3006231                           1.945205
# 3006232                           1.956164
# 3006233                           1.967123
# (70578, 24)
#           date  store_nbr  sales_store_lag16  sales_store_lag17  \
# 380 2014-01-17          1           0.000000        4618.153000
# 381 2014-01-18          1       12034.864999           0.000000
# 382 2014-01-19          1       11700.451400       12034.864999
# 383 2014-01-20          1       10863.582000       11700.451400
# 384 2014-01-21          1        4634.573000       10863.582000
#
#      sales_store_lag18  sales_store_lag19  sales_store_lag20  \
# 380        5754.394980        1819.251996        4532.439000
# 381        4618.153000        5754.394980        1819.251996
# 382           0.000000        4618.153000        5754.394980
# 383       12034.864999           0.000000        4618.153000
# 384       11700.451400       12034.864999           0.000000
#
#      sales_store_lag21  sales_store_lag22  sales_store_lag30  \
# 380        7440.179000        6151.595000         9382.83803
# 381        4532.439000        7440.179000         7930.98600
# 382        1819.251996        4532.439000        10906.77801
# 383        5754.394980        1819.251996         8320.06300
# 384        4618.153000        5754.394980         5450.84600
#
#      sales_store_lag60  sales_store_lag90  sales_store_lag120  \
# 380        6396.040030        5723.311020          5064.11799
# 381        6475.073999        2550.309995          5621.10698
# 382        7099.558000        5879.459000          5573.48200
# 383        5481.078000        5429.208000          2216.21000
# 384        6937.855000        6429.410990          5487.16900
#
#      sales_store_lag150  sales_store_lag180  sales_store_lag210  \
# 380         4658.069996            1905.670            5608.436
# 381         5531.862000            5047.601            5257.657
# 382         4568.639000            5644.173            2207.966
# 383         5678.172998            5855.491            5225.463
# 384         4615.946000            5112.657            5698.107
#
#      sales_store_lag240  sales_store_lag270  sales_store_lag300  \
# 380         5896.853000         5504.771000          5518.59600
# 381         5426.115000         5085.243000          2056.88000
# 382         2195.219000         7112.197000          5233.41299
# 383         4255.778004         4722.563002          4812.27600
# 384         1621.783000         6316.556000          6387.45500
#
#      sales_store_lag330  sales_store_lag360  ema_sales_store_lag_16_22  \
# 380         5325.731000          5298.98600                4082.077424
# 381         5781.510002          6259.34600                6070.274318
# 382         5426.989018          4861.52400                7477.818588
# 383         2295.712000          5577.70100                8324.259441
# 384         5333.274984          5290.32701                7401.837831
#
#      ema_sales_store_lag_16_45  ema_sales_store_lag_16_380
# 380                6532.610967                 5214.379628
# 381                6722.666533                 5227.030907
# 382                6807.393413                 5242.995859
# 383                6972.171147                 5256.540251
# 384                7023.522413                 5251.925971
#             date  store_nbr  sales_store_lag16  sales_store_lag17  \
# 91093 2017-08-11         54        6572.494000        8241.906000
# 91094 2017-08-12         54        6911.345000        6572.494000
# 91095 2017-08-13         54        9531.089998        6911.345000
# 91096 2017-08-14         54       10878.746000        9531.089998
# 91097 2017-08-15         54       15815.709996       10878.746000
#
#        sales_store_lag18  sales_store_lag19  sales_store_lag20  \
# 91093       10245.246998       16841.417000        9739.265000
# 91094        8241.906000       10245.246998       16841.417000
# 91095        6572.494000        8241.906000       10245.246998
# 91096        6911.345000        6572.494000        8241.906000
# 91097        9531.089998        6911.345000        6572.494000
#
#        sales_store_lag21  sales_store_lag22  sales_store_lag30  \
# 91093       10845.986000        7097.149003        8042.298000
# 91094        9739.265000       10845.986000        6722.425000
# 91095       16841.417000        9739.265000        6765.057998
# 91096       10245.246998       16841.417000        9306.720000
# 91097        8241.906000       10245.246998       16959.135000
#
#        sales_store_lag60  sales_store_lag90  sales_store_lag120  \
# 91093       11821.521000          11318.824         7956.353002
# 91094        9262.571000          11251.186         6093.959000
# 91095        9678.241998          13391.214         8845.043000
# 91096        6506.621000           9195.975        10599.092000
# 91097       10540.249999          17721.085         8402.924000
#
#        sales_store_lag150  sales_store_lag180  sales_store_lag210  \
# 91093         8192.171000        11721.063000            7262.782
# 91094         7520.890000         8257.622000            8834.506
# 91095         5348.335998         6807.944000           11633.912
# 91096         7928.360000         7077.091998            9775.383
# 91097        10604.055000         5518.609000            7374.671
#
#        sales_store_lag240  sales_store_lag270  sales_store_lag300  \
# 91093         6872.459002        10855.031002            8966.580
# 91094         6923.343000         9892.957000           13494.297
# 91095         8206.350995         7604.733000            8572.510
# 91096         9473.449002         9304.739002            8637.075
# 91097        12540.281000         5940.149002            6340.114
#
#        sales_store_lag330  sales_store_lag360  ema_sales_store_lag_16_22  \
# 91093         6323.353000         7951.739006                9412.730787
# 91094         6812.701002         6246.614000                8787.384341
# 91095         8997.745000         6128.879997                8973.310755
# 91096        12835.125000         6315.900000                9449.669566
# 91097         8185.356998         8424.711000               11041.179674
#
#        ema_sales_store_lag_16_45  ema_sales_store_lag_16_380
# 91093                9832.126766                 8773.782915
# 91094                9776.435700                 8776.847039
# 91095                9865.920500                 8789.411924
# 91096                9927.366300                 8801.114677
# 91097               10163.706700                 8816.963789
# (43131, 24)
#           date      family  sales_family_lag16  sales_family_lag17  \
# 380 2014-01-17  AUTOMOTIVE                 4.0               239.0
# 381 2014-01-18  AUTOMOTIVE               331.0                 4.0
# 382 2014-01-19  AUTOMOTIVE               299.0               331.0
# 383 2014-01-20  AUTOMOTIVE               404.0               299.0
# 384 2014-01-21  AUTOMOTIVE               393.0               404.0
#
#      sales_family_lag18  sales_family_lag19  sales_family_lag20  \
# 380               389.0               386.0               432.0
# 381               239.0               389.0               386.0
# 382                 4.0               239.0               389.0
# 383               331.0                 4.0               239.0
# 384               299.0               331.0                 4.0
#
#      sales_family_lag21  sales_family_lag22  sales_family_lag30  \
# 380               297.0               317.0               198.0
# 381               432.0               297.0               196.0
# 382               386.0               432.0               225.0
# 383               389.0               386.0               325.0
# 384               239.0               389.0               365.0
#
#      sales_family_lag60  sales_family_lag90  sales_family_lag120  \
# 380               200.0               329.0                159.0
# 381               176.0               381.0                190.0
# 382               238.0               193.0                306.0
# 383               200.0               206.0                346.0
# 384               182.0               174.0                201.0
#
#      sales_family_lag150  sales_family_lag180  sales_family_lag210  \
# 380                224.0                364.0                206.0
# 381                240.0                296.0                377.0
# 382                215.0                258.0                390.0
# 383                204.0                294.0                212.0
# 384                317.0                223.0                256.0
#
#      sales_family_lag240  sales_family_lag270  sales_family_lag300  \
# 380                284.0                206.0                344.0
# 381                308.0                203.0                313.0
# 382                362.0                268.0                227.0
# 383                368.0                244.0                183.0
# 384                360.0                194.0                216.0
#
#      sales_family_lag330  sales_family_lag360  ema_sales_family_lag_16_22  \
# 380                164.0                163.0                  242.154764
# 381                181.0                198.0                  264.366073
# 382                275.0                156.0                  273.024555
# 383                390.0                177.0                  305.768416
# 384                220.0                302.0                  327.576312
#
#      ema_sales_family_lag_16_45  ema_sales_family_lag_16_380
# 380                  264.933333                   253.635616
# 381                  266.400000                   253.843836
# 382                  268.700000                   254.221918
# 383                  274.733333                   254.865753
# 384                  280.566667                   255.005479
#             date   family  sales_family_lag16  sales_family_lag17  \
# 55666 2017-08-11  SEAFOOD          839.655002          842.090999
# 55667 2017-08-12  SEAFOOD          652.069999          839.655002
# 55668 2017-08-13  SEAFOOD         1307.945999          652.069999
# 55669 2017-08-14  SEAFOOD         1297.514006         1307.945999
# 55670 2017-08-15  SEAFOOD         1379.617003         1297.514006
#
#        sales_family_lag18  sales_family_lag19  sales_family_lag20  \
# 55666          995.327001         1336.117001         1237.136004
# 55667          842.090999          995.327001         1336.117001
# 55668          839.655002          842.090999          995.327001
# 55669          652.069999          839.655002          842.090999
# 55670         1307.945999          652.069999          839.655002
#
#        sales_family_lag21  sales_family_lag22  sales_family_lag30  \
# 55666         1279.617002          832.490001          910.025003
# 55667         1237.136004         1279.617002          763.185000
# 55668         1336.117001         1237.136004         1168.711002
# 55669          995.327001         1336.117001         1116.871994
# 55670          842.090999          995.327001         1413.877000
#
#        sales_family_lag60  sales_family_lag90  sales_family_lag120  \
# 55666          733.046999         1586.752001          1338.790996
# 55667          731.403995         1109.968000          1663.270998
# 55668          853.077994         1176.515991          1219.864000
# 55669          677.453000         1207.565999          1380.766001
# 55670         1315.639001         1195.405000           998.932001
#
#        sales_family_lag150  sales_family_lag180  sales_family_lag210  \
# 55666          1122.169993          1549.751998          1499.210012
# 55667          1316.079002          1092.972998          1449.434000
# 55668          1143.293005           889.708000          1597.529992
# 55669          1855.046000           981.652003          1101.452004
# 55670          1597.305998           858.070005           990.695003
#
#        sales_family_lag240  sales_family_lag270  sales_family_lag300  \
# 55666          1000.610003          1168.591997          1412.043001
# 55667           668.240001          1081.247003          1833.255003
# 55668          1297.765000          1279.605003          1152.918007
# 55669          1157.602995           787.699001          1006.996007
# 55670          1289.671995          1362.009002          1080.609002
#
#        sales_family_lag330  sales_family_lag360  ema_sales_family_lag_16_22  \
# 55666           914.278999          1231.333995                  994.971666
# 55667          1648.302995          1272.509000                  909.246249
# 55668          1526.577002          1005.604001                 1008.921187
# 55669          1624.924003          1577.567993                 1081.069392
# 55670          1138.018999          1447.197998                 1155.706294
#
#        ema_sales_family_lag_16_45  ema_sales_family_lag_16_380
# 55666                 1106.508366                  1214.055734
# 55667                 1097.978233                  1213.060436
# 55668                 1110.908100                  1214.387918
# 55669                 1130.908133                  1213.776773
# 55670                 1131.143900                  1213.799340

# %%
df = df.merge(df_stores, on=['date', 'store_nbr'], how='inner')
del df_stores

df = df.merge(df_families, on=['date', 'family'], how='inner')
del df_families

verify(df)
# Out:
# (2329074, 76)
#         date  store_nbr      family  sales  onpromotion  year  month  day  \
# 0 2014-01-17          1  AUTOMOTIVE    2.0            0  2014      1   17
# 1 2014-01-17          2  AUTOMOTIVE    7.0            0  2014      1   17
# 2 2014-01-17          3  AUTOMOTIVE    9.0            0  2014      1   17
# 3 2014-01-17          4  AUTOMOTIVE    5.0            0  2014      1   17
# 4 2014-01-17          5  AUTOMOTIVE    4.0            0  2014      1   17
#
#    day_of_week  business_day  sales_store_family_lag16  \
# 0            4             0                       0.0
# 1            4             0                       0.0
# 2            4             0                       0.0
# 3            4             0                       0.0
# 4            4             0                       0.0
#
#    sales_store_family_lag17  sales_store_family_lag18  \
# 0                       2.0                       1.0
# 1                       8.0                       6.0
# 2                       2.0                      10.0
# 3                       2.0                       6.0
# 4                       2.0                       5.0
#
#    sales_store_family_lag19  sales_store_family_lag20  \
# 0                       0.0                       4.0
# 1                       3.0                       5.0
# 2                      15.0                       9.0
# 3                      11.0                       5.0
# 4                       6.0                       5.0
#
#    sales_store_family_lag21  sales_store_family_lag22  \
# 0                       6.0                       2.0
# 1                       8.0                       2.0
# 2                       6.0                       8.0
# 3                       2.0                       7.0
# 4                      11.0                       2.0
#
#    sales_store_family_lag30  sales_store_family_lag60  \
# 0                       1.0                       1.0
# 1                       6.0                       2.0
# 2                       3.0                       1.0
# 3                       2.0                       5.0
# 4                       3.0                       4.0
#
#    sales_store_family_lag90  sales_store_family_lag120  \
# 0                       1.0                        2.0
# 1                       6.0                        4.0
# 2                      12.0                        4.0
# 3                       1.0                        1.0
# 4                       6.0                        2.0
#
#    sales_store_family_lag150  sales_store_family_lag180  \
# 0                        1.0                        1.0
# 1                        3.0                        2.0
# 2                        7.0                        5.0
# 3                        5.0                        3.0
# 4                        6.0                        8.0
#
#    sales_store_family_lag210  sales_store_family_lag240  \
# 0                        5.0                        1.0
# 1                        1.0                        2.0
# 2                       11.0                        3.0
# 3                        1.0                        2.0
# 4                        1.0                        2.0
#
#    sales_store_family_lag270  sales_store_family_lag300  \
# 0                        2.0                        0.0
# 1                        1.0                        6.0
# 2                        3.0                        7.0
# 3                        2.0                        8.0
# 4                        2.0                        3.0
#
#    sales_store_family_lag330  sales_store_family_lag360  \
# 0                        1.0                        1.0
# 1                        4.0                        2.0
# 2                        3.0                        3.0
# 3                        5.0                        0.0
# 4                        2.0                        7.0
#
#    ema_sales_store_family_lag_16_22  ema_sales_store_family_lag_16_45  \
# 0                          1.474098                          1.833333
# 1                          4.404975                          4.300000
# 2                          5.542701                          5.900000
# 3                          3.920018                          4.233333
# 4                          3.284882                          4.300000
#
#    ema_sales_store_family_lag_16_380  sales_store_lag16  sales_store_lag17  \
# 0                           2.142466                0.0          4618.1530
# 1                           3.693151                0.0         10784.2400
# 2                           7.005479                0.0         20350.2601
# 3                           4.010959                0.0         10644.7940
# 4                           4.446575                0.0         11653.2340
#
#    sales_store_lag18  sales_store_lag19  sales_store_lag20  sales_store_lag21  \
# 0         5754.39498        1819.251996        4532.439000         7440.17900
# 1        10471.02300        7575.103970        8975.967000         8798.07800
# 2        25879.01500       18258.696000       21290.041985        19884.88404
# 3        10491.67600        7533.109010        8934.769000         8538.42300
# 4        14030.74000        9906.029000       10650.379040        10926.64800
#
#    sales_store_lag22  sales_store_lag30  sales_store_lag60  sales_store_lag90  \
# 0        6151.595000         9382.83803        6396.040030        5723.311020
# 1        8370.093030        10808.05100        7932.985000       10556.369999
# 2       21118.824030        24811.25400       17359.445998       24412.431000
# 3        7036.212998         7780.48600        6558.057000        8659.599000
# 4        9302.268000         8913.48400        6423.434000        7281.101980
#
#    sales_store_lag120  sales_store_lag150  sales_store_lag180  \
# 0          5064.11799         4658.069996          1905.67000
# 1          5589.83701         7364.131996          8322.35700
# 2         12854.20700        15038.870980         20147.16797
# 3          4549.53699         6233.079000          8906.79000
# 4          4874.79900         5928.438000          8489.36800
#
#    sales_store_lag210  sales_store_lag240  sales_store_lag270  \
# 0         5608.436000         5896.853000         5504.771000
# 1         7312.826996         6642.774000         7047.772000
# 2        15494.618000        13900.119000        15323.494000
# 3         5507.104000         5259.091998         6066.549011
# 4         5749.733000         5472.496990         6319.163010
#
#    sales_store_lag300  sales_store_lag330  sales_store_lag360  \
# 0         5518.596000         5325.731000         5298.986000
# 1        10146.848000         5138.403004         6157.080001
# 2        20366.300000        12110.657000        12857.139024
# 3         8921.207978         4989.730000         5389.751990
# 4         6389.314000         5130.570000         6079.274000
#
#    ema_sales_store_lag_16_22  ema_sales_store_lag_16_45  \
# 0                4082.077424                6532.610967
# 1                7584.884739                9909.063967
# 2               16574.644444               22231.457402
# 3                7432.554631                8902.319868
# 4                8935.970934                9842.768936
#
#    ema_sales_store_lag_16_380  sales_family_lag16  sales_family_lag17  \
# 0                 5214.379628                 4.0               239.0
# 1                 7884.668154                 4.0               239.0
# 2                17765.341120                 4.0               239.0
# 3                 7189.951863                 4.0               239.0
# 4                 7106.665439                 4.0               239.0
#
#    sales_family_lag18  sales_family_lag19  sales_family_lag20  \
# 0               389.0               386.0               432.0
# 1               389.0               386.0               432.0
# 2               389.0               386.0               432.0
# 3               389.0               386.0               432.0
# 4               389.0               386.0               432.0
#
#    sales_family_lag21  sales_family_lag22  sales_family_lag30  \
# 0               297.0               317.0               198.0
# 1               297.0               317.0               198.0
# 2               297.0               317.0               198.0
# 3               297.0               317.0               198.0
# 4               297.0               317.0               198.0
#
#    sales_family_lag60  sales_family_lag90  sales_family_lag120  \
# 0               200.0               329.0                159.0
# 1               200.0               329.0                159.0
# 2               200.0               329.0                159.0
# 3               200.0               329.0                159.0
# 4               200.0               329.0                159.0
#
#    sales_family_lag150  sales_family_lag180  sales_family_lag210  \
# 0                224.0                364.0                206.0
# 1                224.0                364.0                206.0
# 2                224.0                364.0                206.0
# 3                224.0                364.0                206.0
# 4                224.0                364.0                206.0
#
#    sales_family_lag240  sales_family_lag270  sales_family_lag300  \
# 0                284.0                206.0                344.0
# 1                284.0                206.0                344.0
# 2                284.0                206.0                344.0
# 3                284.0                206.0                344.0
# 4                284.0                206.0                344.0
#
#    sales_family_lag330  sales_family_lag360  ema_sales_family_lag_16_22  \
# 0                164.0                163.0                  242.154764
# 1                164.0                163.0                  242.154764
# 2                164.0                163.0                  242.154764
# 3                164.0                163.0                  242.154764
# 4                164.0                163.0                  242.154764
#
#    ema_sales_family_lag_16_45  ema_sales_family_lag_16_380
# 0                  264.933333                   253.635616
# 1                  264.933333                   253.635616
# 2                  264.933333                   253.635616
# 3                  264.933333                   253.635616
# 4                  264.933333                   253.635616
#               date  store_nbr   family   sales  onpromotion  year  month  day  \
# 2329069 2017-08-15         50  SEAFOOD  15.314            0  2017      8   15
# 2329070 2017-08-15         51  SEAFOOD  52.876            0  2017      8   15
# 2329071 2017-08-15         52  SEAFOOD   7.000            0  2017      8   15
# 2329072 2017-08-15         53  SEAFOOD   5.000            0  2017      8   15
# 2329073 2017-08-15         54  SEAFOOD   3.000            0  2017      8   15
#
#          day_of_week  business_day  sales_store_family_lag16  \
# 2329069            1             0                    19.564
# 2329070            1             0                    75.666
# 2329071            1             0                    12.000
# 2329072            1             0                     2.000
# 2329073            1             0                     4.000
#
#          sales_store_family_lag17  sales_store_family_lag18  \
# 2329069                    38.183                    45.765
# 2329070                    54.773                    55.965
# 2329071                    12.000                    12.000
# 2329072                     2.000                     4.000
# 2329073                     4.000                     4.000
#
#          sales_store_family_lag19  sales_store_family_lag20  \
# 2329069                    19.574                 15.565001
# 2329070                    24.253                 40.159000
# 2329071                     8.000                  5.000000
# 2329072                     4.000                  0.000000
# 2329073                     2.000                  3.000000
#
#          sales_store_family_lag21  sales_store_family_lag22  \
# 2329069                    18.085                    11.970
# 2329070                    36.005                    47.489
# 2329071                     8.000                     5.414
# 2329072                     6.000                     2.000
# 2329073                     7.000                     1.000
#
#          sales_store_family_lag30  sales_store_family_lag60  \
# 2329069                 22.605999                     8.000
# 2329070                 59.424000                    58.518
# 2329071                 17.000000                     6.000
# 2329072                  5.000000                     7.000
# 2329073                  5.000000                     2.000
#
#          sales_store_family_lag90  sales_store_family_lag120  \
# 2329069                    18.102                  17.511000
# 2329070                    66.958                  37.850998
# 2329071                     5.000                   0.000000
# 2329072                     3.000                   4.000000
# 2329073                     2.000                   0.000000
#
#          sales_store_family_lag150  sales_store_family_lag180  \
# 2329069                     23.000                      7.000
# 2329070                     53.438                     26.071
# 2329071                      0.000                      0.000
# 2329072                      7.000                      6.000
# 2329073                      3.000                      1.000
#
#          sales_store_family_lag210  sales_store_family_lag240  \
# 2329069                     25.070                     23.528
# 2329070                     44.687                     58.608
# 2329071                      0.000                      0.000
# 2329072                     12.000                      6.000
# 2329073                      2.000                      5.000
#
#          sales_store_family_lag270  sales_store_family_lag300  \
# 2329069                  25.161000                     27.047
# 2329070                  66.229004                     54.069
# 2329071                   0.000000                      0.000
# 2329072                  14.000000                      3.000
# 2329073                   0.000000                      0.000
#
#          sales_store_family_lag330  sales_store_family_lag360  \
# 2329069                  28.487999                     40.402
# 2329070                  63.306000                     88.277
# 2329071                   0.000000                      0.000
# 2329072                   2.000000                      1.000
# 2329073                   0.000000                      2.000
#
#          ema_sales_store_family_lag_16_22  ema_sales_store_family_lag_16_45  \
# 2329069                         25.780637                         21.412933
# 2329070                         54.055013                         50.628067
# 2329071                         10.390481                          9.696067
# 2329072                          2.911979                          3.933333
# 2329073                          3.621519                          3.100000
#
#          ema_sales_store_family_lag_16_380  sales_store_lag16  \
# 2329069                          21.474304       28905.006000
# 2329070                          53.342526       31740.339000
# 2329071                           2.945975       26874.197970
# 2329072                           6.314082       17141.285000
# 2329073                           1.967123       15815.709996
#
#          sales_store_lag17  sales_store_lag18  sales_store_lag19  \
# 2329069        29523.78400       22359.163000       17047.749000
# 2329070        25381.37296       25944.219000       17206.981000
# 2329071        33950.49397       27263.180970       17526.184004
# 2329072        14961.53703       11183.506000        7726.762000
# 2329073        10878.74600        9531.089998        6911.345000
#
#          sales_store_lag20  sales_store_lag21  sales_store_lag22  \
# 2329069       18063.433001          18572.603       20176.261004
# 2329070       25735.891000          21278.683       25309.882000
# 2329071       23978.732000          17653.922       20484.642000
# 2329072       12397.486000           8396.316       11461.163000
# 2329073        6572.494000           8241.906       10245.246998
#
#          sales_store_lag30  sales_store_lag60  sales_store_lag90  \
# 2329069       27946.379999       21381.688000        17301.50200
# 2329070       31024.755000       30187.641020        28664.33003
# 2329071       30216.529000       22425.545000        24600.06500
# 2329072       16387.040000       12498.094000        11484.32000
# 2329073       16959.135000       10540.249999        17721.08500
#
#          sales_store_lag120  sales_store_lag150  sales_store_lag180  \
# 2329069        18540.736000         30445.08500           14912.749
# 2329070        23268.793998         25029.97804           18654.792
# 2329071            0.000000             0.00000               0.000
# 2329072        10786.439000         14720.72200            9047.348
# 2329073         8402.924000         10604.05500            5518.609
#
#          sales_store_lag210  sales_store_lag240  sales_store_lag270  \
# 2329069           17249.560        37987.356995        19786.152000
# 2329070           22051.198        36331.785000        25291.539004
# 2329071               0.000            0.000000            0.000000
# 2329072           10468.129        19251.229000        10280.446000
# 2329073            7374.671        12540.281000         5940.149002
#
#          sales_store_lag300  sales_store_lag330  sales_store_lag360  \
# 2329069         14007.13798        16744.163999        19723.386020
# 2329070         23468.32797        20768.452010        27109.459000
# 2329071             0.00000            0.000000            0.000000
# 2329072          9647.29400         9941.111000        15296.490004
# 2329073          6340.11400         8185.356998         8424.711000
#
#          ema_sales_store_lag_16_22  ema_sales_store_lag_16_45  \
# 2329069               24268.343902               22556.048994
# 2329070               25726.025906               24509.603702
# 2329071               25903.036360               23262.360796
# 2329072               13194.485283               12230.967169
# 2329073               11041.179674               10163.706700
#
#          ema_sales_store_lag_16_380  sales_family_lag16  sales_family_lag17  \
# 2329069                21448.769026         1379.617003         1297.514006
# 2329070                23697.171516         1379.617003         1297.514006
# 2329071                 6385.428436         1379.617003         1297.514006
# 2329072                12358.954583         1379.617003         1297.514006
# 2329073                 8816.963789         1379.617003         1297.514006
#
#          sales_family_lag18  sales_family_lag19  sales_family_lag20  \
# 2329069         1307.945999          652.069999          839.655002
# 2329070         1307.945999          652.069999          839.655002
# 2329071         1307.945999          652.069999          839.655002
# 2329072         1307.945999          652.069999          839.655002
# 2329073         1307.945999          652.069999          839.655002
#
#          sales_family_lag21  sales_family_lag22  sales_family_lag30  \
# 2329069          842.090999          995.327001            1413.877
# 2329070          842.090999          995.327001            1413.877
# 2329071          842.090999          995.327001            1413.877
# 2329072          842.090999          995.327001            1413.877
# 2329073          842.090999          995.327001            1413.877
#
#          sales_family_lag60  sales_family_lag90  sales_family_lag120  \
# 2329069         1315.639001            1195.405           998.932001
# 2329070         1315.639001            1195.405           998.932001
# 2329071         1315.639001            1195.405           998.932001
# 2329072         1315.639001            1195.405           998.932001
# 2329073         1315.639001            1195.405           998.932001
#
#          sales_family_lag150  sales_family_lag180  sales_family_lag210  \
# 2329069          1597.305998           858.070005           990.695003
# 2329070          1597.305998           858.070005           990.695003
# 2329071          1597.305998           858.070005           990.695003
# 2329072          1597.305998           858.070005           990.695003
# 2329073          1597.305998           858.070005           990.695003
#
#          sales_family_lag240  sales_family_lag270  sales_family_lag300  \
# 2329069          1289.671995          1362.009002          1080.609002
# 2329070          1289.671995          1362.009002          1080.609002
# 2329071          1289.671995          1362.009002          1080.609002
# 2329072          1289.671995          1362.009002          1080.609002
# 2329073          1289.671995          1362.009002          1080.609002
#
#          sales_family_lag330  sales_family_lag360  ema_sales_family_lag_16_22  \
# 2329069          1138.018999          1447.197998                 1155.706294
# 2329070          1138.018999          1447.197998                 1155.706294
# 2329071          1138.018999          1447.197998                 1155.706294
# 2329072          1138.018999          1447.197998                 1155.706294
# 2329073          1138.018999          1447.197998                 1155.706294
#
#          ema_sales_family_lag_16_45  ema_sales_family_lag_16_380
# 2329069                   1131.1439                   1213.79934
# 2329070                   1131.1439                   1213.79934
# 2329071                   1131.1439                   1213.79934
# 2329072                   1131.1439                   1213.79934
# 2329073                   1131.1439                   1213.79934

# %% [markdown]
# # Oil

# %%
df_oil = pd.read_csv('data/oil_clean.csv')

cols_week = []
for lag in list(range(1,8)):
    df_oil[f'dcoilwtico_lag{lag}'] = df_oil.dcoilwtico.shift(lag)
    cols_week.append(f'dcoilwtico_lag{lag}')

df_oil['ema_dcoilwtico_week'] = df_oil.dcoilwtico.ewm(span=7, adjust=False, min_periods=7).mean().reset_index(drop=True)
df_oil['ema_dcoilwtico_lag_1_7'] = df_oil.ema_dcoilwtico_week.shift(1)

df_oil['ema_dcoilwtico_month'] = df_oil.dcoilwtico.rolling(30, min_periods=30).mean().reset_index(drop=True)
df_oil['ema_dcoilwtico_lag_1_30'] = df_oil.ema_dcoilwtico_month.shift(1)

df_oil['ema_dcoilwtico_year'] = df_oil.dcoilwtico.rolling(365, min_periods=365).mean().reset_index(drop=True)
df_oil['ema_dcoilwtico_lag_1_365'] = df_oil.ema_dcoilwtico_month.shift(1)

df_oil.drop(columns=['ema_dcoilwtico_week', 'ema_dcoilwtico_month', 'ema_dcoilwtico_year'], 
            inplace=True)
verify(df_oil)
# Out:
# (1704, 12)
#          date  dcoilwtico  dcoilwtico_lag1  dcoilwtico_lag2  dcoilwtico_lag3  \
# 0  2013-01-01       93.14              NaN              NaN              NaN
# 1  2013-01-02       93.14            93.14              NaN              NaN
# 2  2013-01-03       92.97            93.14            93.14              NaN
# 3  2013-01-04       93.12            92.97            93.14            93.14
# 4  2013-01-05       93.12            93.12            92.97            93.14
#
#    dcoilwtico_lag4  dcoilwtico_lag5  dcoilwtico_lag6  dcoilwtico_lag7  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4            93.14              NaN              NaN              NaN
#
#    ema_dcoilwtico_lag_1_7  ema_dcoilwtico_lag_1_30  ema_dcoilwtico_lag_1_365
# 0                     NaN                      NaN                       NaN
# 1                     NaN                      NaN                       NaN
# 2                     NaN                      NaN                       NaN
# 3                     NaN                      NaN                       NaN
# 4                     NaN                      NaN                       NaN
#             date  dcoilwtico  dcoilwtico_lag1  dcoilwtico_lag2  \
# 1699  2017-08-27       47.65            47.65            47.65
# 1700  2017-08-28       46.40            47.65            47.65
# 1701  2017-08-29       46.46            46.40            47.65
# 1702  2017-08-30       45.96            46.46            46.40
# 1703  2017-08-31       47.26            45.96            46.46
#
#       dcoilwtico_lag3  dcoilwtico_lag4  dcoilwtico_lag5  dcoilwtico_lag6  \
# 1699            47.24            48.45            47.65            47.39
# 1700            47.65            47.24            48.45            47.65
# 1701            47.65            47.65            47.24            48.45
# 1702            47.65            47.65            47.65            47.24
# 1703            46.40            47.65            47.65            47.65
#
#       dcoilwtico_lag7  ema_dcoilwtico_lag_1_7  ema_dcoilwtico_lag_1_30  \
# 1699            48.59               47.765076                48.657667
# 1700            47.39               47.736307                48.588667
# 1701            47.65               47.402230                48.478000
# 1702            48.45               47.166673                48.369333
# 1703            47.24               46.865004                48.227667
#
#       ema_dcoilwtico_lag_1_365
# 1699                 48.657667
# 1700                 48.588667
# 1701                 48.478000
# 1702                 48.369333
# 1703                 48.227667

# %%
df_oil['date'] = pd.to_datetime(df_oil['date'])

# %%
df = df.merge(df_oil, on='date', how='left')
verify(df)
# Out:
# (2329074, 87)
#         date  store_nbr      family  sales  onpromotion  year  month  day  \
# 0 2014-01-17          1  AUTOMOTIVE    2.0            0  2014      1   17
# 1 2014-01-17          2  AUTOMOTIVE    7.0            0  2014      1   17
# 2 2014-01-17          3  AUTOMOTIVE    9.0            0  2014      1   17
# 3 2014-01-17          4  AUTOMOTIVE    5.0            0  2014      1   17
# 4 2014-01-17          5  AUTOMOTIVE    4.0            0  2014      1   17
#
#    day_of_week  business_day  sales_store_family_lag16  \
# 0            4             0                       0.0
# 1            4             0                       0.0
# 2            4             0                       0.0
# 3            4             0                       0.0
# 4            4             0                       0.0
#
#    sales_store_family_lag17  sales_store_family_lag18  \
# 0                       2.0                       1.0
# 1                       8.0                       6.0
# 2                       2.0                      10.0
# 3                       2.0                       6.0
# 4                       2.0                       5.0
#
#    sales_store_family_lag19  sales_store_family_lag20  \
# 0                       0.0                       4.0
# 1                       3.0                       5.0
# 2                      15.0                       9.0
# 3                      11.0                       5.0
# 4                       6.0                       5.0
#
#    sales_store_family_lag21  sales_store_family_lag22  \
# 0                       6.0                       2.0
# 1                       8.0                       2.0
# 2                       6.0                       8.0
# 3                       2.0                       7.0
# 4                      11.0                       2.0
#
#    sales_store_family_lag30  sales_store_family_lag60  \
# 0                       1.0                       1.0
# 1                       6.0                       2.0
# 2                       3.0                       1.0
# 3                       2.0                       5.0
# 4                       3.0                       4.0
#
#    sales_store_family_lag90  sales_store_family_lag120  \
# 0                       1.0                        2.0
# 1                       6.0                        4.0
# 2                      12.0                        4.0
# 3                       1.0                        1.0
# 4                       6.0                        2.0
#
#    sales_store_family_lag150  sales_store_family_lag180  \
# 0                        1.0                        1.0
# 1                        3.0                        2.0
# 2                        7.0                        5.0
# 3                        5.0                        3.0
# 4                        6.0                        8.0
#
#    sales_store_family_lag210  sales_store_family_lag240  \
# 0                        5.0                        1.0
# 1                        1.0                        2.0
# 2                       11.0                        3.0
# 3                        1.0                        2.0
# 4                        1.0                        2.0
#
#    sales_store_family_lag270  sales_store_family_lag300  \
# 0                        2.0                        0.0
# 1                        1.0                        6.0
# 2                        3.0                        7.0
# 3                        2.0                        8.0
# 4                        2.0                        3.0
#
#    sales_store_family_lag330  sales_store_family_lag360  \
# 0                        1.0                        1.0
# 1                        4.0                        2.0
# 2                        3.0                        3.0
# 3                        5.0                        0.0
# 4                        2.0                        7.0
#
#    ema_sales_store_family_lag_16_22  ema_sales_store_family_lag_16_45  \
# 0                          1.474098                          1.833333
# 1                          4.404975                          4.300000
# 2                          5.542701                          5.900000
# 3                          3.920018                          4.233333
# 4                          3.284882                          4.300000
#
#    ema_sales_store_family_lag_16_380  sales_store_lag16  sales_store_lag17  \
# 0                           2.142466                0.0          4618.1530
# 1                           3.693151                0.0         10784.2400
# 2                           7.005479                0.0         20350.2601
# 3                           4.010959                0.0         10644.7940
# 4                           4.446575                0.0         11653.2340
#
#    sales_store_lag18  sales_store_lag19  sales_store_lag20  sales_store_lag21  \
# 0         5754.39498        1819.251996        4532.439000         7440.17900
# 1        10471.02300        7575.103970        8975.967000         8798.07800
# 2        25879.01500       18258.696000       21290.041985        19884.88404
# 3        10491.67600        7533.109010        8934.769000         8538.42300
# 4        14030.74000        9906.029000       10650.379040        10926.64800
#
#    sales_store_lag22  sales_store_lag30  sales_store_lag60  sales_store_lag90  \
# 0        6151.595000         9382.83803        6396.040030        5723.311020
# 1        8370.093030        10808.05100        7932.985000       10556.369999
# 2       21118.824030        24811.25400       17359.445998       24412.431000
# 3        7036.212998         7780.48600        6558.057000        8659.599000
# 4        9302.268000         8913.48400        6423.434000        7281.101980
#
#    sales_store_lag120  sales_store_lag150  sales_store_lag180  \
# 0          5064.11799         4658.069996          1905.67000
# 1          5589.83701         7364.131996          8322.35700
# 2         12854.20700        15038.870980         20147.16797
# 3          4549.53699         6233.079000          8906.79000
# 4          4874.79900         5928.438000          8489.36800
#
#    sales_store_lag210  sales_store_lag240  sales_store_lag270  \
# 0         5608.436000         5896.853000         5504.771000
# 1         7312.826996         6642.774000         7047.772000
# 2        15494.618000        13900.119000        15323.494000
# 3         5507.104000         5259.091998         6066.549011
# 4         5749.733000         5472.496990         6319.163010
#
#    sales_store_lag300  sales_store_lag330  sales_store_lag360  \
# 0         5518.596000         5325.731000         5298.986000
# 1        10146.848000         5138.403004         6157.080001
# 2        20366.300000        12110.657000        12857.139024
# 3         8921.207978         4989.730000         5389.751990
# 4         6389.314000         5130.570000         6079.274000
#
#    ema_sales_store_lag_16_22  ema_sales_store_lag_16_45  \
# 0                4082.077424                6532.610967
# 1                7584.884739                9909.063967
# 2               16574.644444               22231.457402
# 3                7432.554631                8902.319868
# 4                8935.970934                9842.768936
#
#    ema_sales_store_lag_16_380  sales_family_lag16  sales_family_lag17  \
# 0                 5214.379628                 4.0               239.0
# 1                 7884.668154                 4.0               239.0
# 2                17765.341120                 4.0               239.0
# 3                 7189.951863                 4.0               239.0
# 4                 7106.665439                 4.0               239.0
#
#    sales_family_lag18  sales_family_lag19  sales_family_lag20  \
# 0               389.0               386.0               432.0
# 1               389.0               386.0               432.0
# 2               389.0               386.0               432.0
# 3               389.0               386.0               432.0
# 4               389.0               386.0               432.0
#
#    sales_family_lag21  sales_family_lag22  sales_family_lag30  \
# 0               297.0               317.0               198.0
# 1               297.0               317.0               198.0
# 2               297.0               317.0               198.0
# 3               297.0               317.0               198.0
# 4               297.0               317.0               198.0
#
#    sales_family_lag60  sales_family_lag90  sales_family_lag120  \
# 0               200.0               329.0                159.0
# 1               200.0               329.0                159.0
# 2               200.0               329.0                159.0
# 3               200.0               329.0                159.0
# 4               200.0               329.0                159.0
#
#    sales_family_lag150  sales_family_lag180  sales_family_lag210  \
# 0                224.0                364.0                206.0
# 1                224.0                364.0                206.0
# 2                224.0                364.0                206.0
# 3                224.0                364.0                206.0
# 4                224.0                364.0                206.0
#
#    sales_family_lag240  sales_family_lag270  sales_family_lag300  \
# 0                284.0                206.0                344.0
# 1                284.0                206.0                344.0
# 2                284.0                206.0                344.0
# 3                284.0                206.0                344.0
# 4                284.0                206.0                344.0
#
#    sales_family_lag330  sales_family_lag360  ema_sales_family_lag_16_22  \
# 0                164.0                163.0                  242.154764
# 1                164.0                163.0                  242.154764
# 2                164.0                163.0                  242.154764
# 3                164.0                163.0                  242.154764
# 4                164.0                163.0                  242.154764
#
#    ema_sales_family_lag_16_45  ema_sales_family_lag_16_380  dcoilwtico  \
# 0                  264.933333                   253.635616       93.96
# 1                  264.933333                   253.635616       93.96
# 2                  264.933333                   253.635616       93.96
# 3                  264.933333                   253.635616       93.96
# 4                  264.933333                   253.635616       93.96
#
#    dcoilwtico_lag1  dcoilwtico_lag2  dcoilwtico_lag3  dcoilwtico_lag4  \
# 0            93.54            93.78            92.15            91.45
# 1            93.54            93.78            92.15            91.45
# 2            93.54            93.78            92.15            91.45
# 3            93.54            93.78            92.15            91.45
# 4            93.54            93.78            92.15            91.45
#
#    dcoilwtico_lag5  dcoilwtico_lag6  dcoilwtico_lag7  ema_dcoilwtico_lag_1_7  \
# 0            92.39            92.39            92.39               92.915199
# 1            92.39            92.39            92.39               92.915199
# 2            92.39            92.39            92.39               92.915199
# 3            92.39            92.39            92.39               92.915199
# 4            92.39            92.39            92.39               92.915199
#
#    ema_dcoilwtico_lag_1_30  ema_dcoilwtico_lag_1_365
# 0                95.927333                 95.927333
# 1                95.927333                 95.927333
# 2                95.927333                 95.927333
# 3                95.927333                 95.927333
# 4                95.927333                 95.927333
#               date  store_nbr   family   sales  onpromotion  year  month  day  \
# 2329069 2017-08-15         50  SEAFOOD  15.314            0  2017      8   15
# 2329070 2017-08-15         51  SEAFOOD  52.876            0  2017      8   15
# 2329071 2017-08-15         52  SEAFOOD   7.000            0  2017      8   15
# 2329072 2017-08-15         53  SEAFOOD   5.000            0  2017      8   15
# 2329073 2017-08-15         54  SEAFOOD   3.000            0  2017      8   15
#
#          day_of_week  business_day  sales_store_family_lag16  \
# 2329069            1             0                    19.564
# 2329070            1             0                    75.666
# 2329071            1             0                    12.000
# 2329072            1             0                     2.000
# 2329073            1             0                     4.000
#
#          sales_store_family_lag17  sales_store_family_lag18  \
# 2329069                    38.183                    45.765
# 2329070                    54.773                    55.965
# 2329071                    12.000                    12.000
# 2329072                     2.000                     4.000
# 2329073                     4.000                     4.000
#
#          sales_store_family_lag19  sales_store_family_lag20  \
# 2329069                    19.574                 15.565001
# 2329070                    24.253                 40.159000
# 2329071                     8.000                  5.000000
# 2329072                     4.000                  0.000000
# 2329073                     2.000                  3.000000
#
#          sales_store_family_lag21  sales_store_family_lag22  \
# 2329069                    18.085                    11.970
# 2329070                    36.005                    47.489
# 2329071                     8.000                     5.414
# 2329072                     6.000                     2.000
# 2329073                     7.000                     1.000
#
#          sales_store_family_lag30  sales_store_family_lag60  \
# 2329069                 22.605999                     8.000
# 2329070                 59.424000                    58.518
# 2329071                 17.000000                     6.000
# 2329072                  5.000000                     7.000
# 2329073                  5.000000                     2.000
#
#          sales_store_family_lag90  sales_store_family_lag120  \
# 2329069                    18.102                  17.511000
# 2329070                    66.958                  37.850998
# 2329071                     5.000                   0.000000
# 2329072                     3.000                   4.000000
# 2329073                     2.000                   0.000000
#
#          sales_store_family_lag150  sales_store_family_lag180  \
# 2329069                     23.000                      7.000
# 2329070                     53.438                     26.071
# 2329071                      0.000                      0.000
# 2329072                      7.000                      6.000
# 2329073                      3.000                      1.000
#
#          sales_store_family_lag210  sales_store_family_lag240  \
# 2329069                     25.070                     23.528
# 2329070                     44.687                     58.608
# 2329071                      0.000                      0.000
# 2329072                     12.000                      6.000
# 2329073                      2.000                      5.000
#
#          sales_store_family_lag270  sales_store_family_lag300  \
# 2329069                  25.161000                     27.047
# 2329070                  66.229004                     54.069
# 2329071                   0.000000                      0.000
# 2329072                  14.000000                      3.000
# 2329073                   0.000000                      0.000
#
#          sales_store_family_lag330  sales_store_family_lag360  \
# 2329069                  28.487999                     40.402
# 2329070                  63.306000                     88.277
# 2329071                   0.000000                      0.000
# 2329072                   2.000000                      1.000
# 2329073                   0.000000                      2.000
#
#          ema_sales_store_family_lag_16_22  ema_sales_store_family_lag_16_45  \
# 2329069                         25.780637                         21.412933
# 2329070                         54.055013                         50.628067
# 2329071                         10.390481                          9.696067
# 2329072                          2.911979                          3.933333
# 2329073                          3.621519                          3.100000
#
#          ema_sales_store_family_lag_16_380  sales_store_lag16  \
# 2329069                          21.474304       28905.006000
# 2329070                          53.342526       31740.339000
# 2329071                           2.945975       26874.197970
# 2329072                           6.314082       17141.285000
# 2329073                           1.967123       15815.709996
#
#          sales_store_lag17  sales_store_lag18  sales_store_lag19  \
# 2329069        29523.78400       22359.163000       17047.749000
# 2329070        25381.37296       25944.219000       17206.981000
# 2329071        33950.49397       27263.180970       17526.184004
# 2329072        14961.53703       11183.506000        7726.762000
# 2329073        10878.74600        9531.089998        6911.345000
#
#          sales_store_lag20  sales_store_lag21  sales_store_lag22  \
# 2329069       18063.433001          18572.603       20176.261004
# 2329070       25735.891000          21278.683       25309.882000
# 2329071       23978.732000          17653.922       20484.642000
# 2329072       12397.486000           8396.316       11461.163000
# 2329073        6572.494000           8241.906       10245.246998
#
#          sales_store_lag30  sales_store_lag60  sales_store_lag90  \
# 2329069       27946.379999       21381.688000        17301.50200
# 2329070       31024.755000       30187.641020        28664.33003
# 2329071       30216.529000       22425.545000        24600.06500
# 2329072       16387.040000       12498.094000        11484.32000
# 2329073       16959.135000       10540.249999        17721.08500
#
#          sales_store_lag120  sales_store_lag150  sales_store_lag180  \
# 2329069        18540.736000         30445.08500           14912.749
# 2329070        23268.793998         25029.97804           18654.792
# 2329071            0.000000             0.00000               0.000
# 2329072        10786.439000         14720.72200            9047.348
# 2329073         8402.924000         10604.05500            5518.609
#
#          sales_store_lag210  sales_store_lag240  sales_store_lag270  \
# 2329069           17249.560        37987.356995        19786.152000
# 2329070           22051.198        36331.785000        25291.539004
# 2329071               0.000            0.000000            0.000000
# 2329072           10468.129        19251.229000        10280.446000
# 2329073            7374.671        12540.281000         5940.149002
#
#          sales_store_lag300  sales_store_lag330  sales_store_lag360  \
# 2329069         14007.13798        16744.163999        19723.386020
# 2329070         23468.32797        20768.452010        27109.459000
# 2329071             0.00000            0.000000            0.000000
# 2329072          9647.29400         9941.111000        15296.490004
# 2329073          6340.11400         8185.356998         8424.711000
#
#          ema_sales_store_lag_16_22  ema_sales_store_lag_16_45  \
# 2329069               24268.343902               22556.048994
# 2329070               25726.025906               24509.603702
# 2329071               25903.036360               23262.360796
# 2329072               13194.485283               12230.967169
# 2329073               11041.179674               10163.706700
#
#          ema_sales_store_lag_16_380  sales_family_lag16  sales_family_lag17  \
# 2329069                21448.769026         1379.617003         1297.514006
# 2329070                23697.171516         1379.617003         1297.514006
# 2329071                 6385.428436         1379.617003         1297.514006
# 2329072                12358.954583         1379.617003         1297.514006
# 2329073                 8816.963789         1379.617003         1297.514006
#
#          sales_family_lag18  sales_family_lag19  sales_family_lag20  \
# 2329069         1307.945999          652.069999          839.655002
# 2329070         1307.945999          652.069999          839.655002
# 2329071         1307.945999          652.069999          839.655002
# 2329072         1307.945999          652.069999          839.655002
# 2329073         1307.945999          652.069999          839.655002
#
#          sales_family_lag21  sales_family_lag22  sales_family_lag30  \
# 2329069          842.090999          995.327001            1413.877
# 2329070          842.090999          995.327001            1413.877
# 2329071          842.090999          995.327001            1413.877
# 2329072          842.090999          995.327001            1413.877
# 2329073          842.090999          995.327001            1413.877
#
#          sales_family_lag60  sales_family_lag90  sales_family_lag120  \
# 2329069         1315.639001            1195.405           998.932001
# 2329070         1315.639001            1195.405           998.932001
# 2329071         1315.639001            1195.405           998.932001
# 2329072         1315.639001            1195.405           998.932001
# 2329073         1315.639001            1195.405           998.932001
#
#          sales_family_lag150  sales_family_lag180  sales_family_lag210  \
# 2329069          1597.305998           858.070005           990.695003
# 2329070          1597.305998           858.070005           990.695003
# 2329071          1597.305998           858.070005           990.695003
# 2329072          1597.305998           858.070005           990.695003
# 2329073          1597.305998           858.070005           990.695003
#
#          sales_family_lag240  sales_family_lag270  sales_family_lag300  \
# 2329069          1289.671995          1362.009002          1080.609002
# 2329070          1289.671995          1362.009002          1080.609002
# 2329071          1289.671995          1362.009002          1080.609002
# 2329072          1289.671995          1362.009002          1080.609002
# 2329073          1289.671995          1362.009002          1080.609002
#
#          sales_family_lag330  sales_family_lag360  ema_sales_family_lag_16_22  \
# 2329069          1138.018999          1447.197998                 1155.706294
# 2329070          1138.018999          1447.197998                 1155.706294
# 2329071          1138.018999          1447.197998                 1155.706294
# 2329072          1138.018999          1447.197998                 1155.706294
# 2329073          1138.018999          1447.197998                 1155.706294
#
#          ema_sales_family_lag_16_45  ema_sales_family_lag_16_380  dcoilwtico  \
# 2329069                   1131.1439                   1213.79934       47.57
# 2329070                   1131.1439                   1213.79934       47.57
# 2329071                   1131.1439                   1213.79934       47.57
# 2329072                   1131.1439                   1213.79934       47.57
# 2329073                   1131.1439                   1213.79934       47.57
#
#          dcoilwtico_lag1  dcoilwtico_lag2  dcoilwtico_lag3  dcoilwtico_lag4  \
# 2329069            47.59            48.81            48.81            48.81
# 2329070            47.59            48.81            48.81            48.81
# 2329071            47.59            48.81            48.81            48.81
# 2329072            47.59            48.81            48.81            48.81
# 2329073            47.59            48.81            48.81            48.81
#
#          dcoilwtico_lag5  dcoilwtico_lag6  dcoilwtico_lag7  \
# 2329069            48.54            49.59            49.07
# 2329070            48.54            49.59            49.07
# 2329071            48.54            49.59            49.07
# 2329072            48.54            49.59            49.07
# 2329073            48.54            49.59            49.07
#
#          ema_dcoilwtico_lag_1_7  ema_dcoilwtico_lag_1_30  \
# 2329069                48.62108                   48.274
# 2329070                48.62108                   48.274
# 2329071                48.62108                   48.274
# 2329072                48.62108                   48.274
# 2329073                48.62108                   48.274
#
#          ema_dcoilwtico_lag_1_365
# 2329069                    48.274
# 2329070                    48.274
# 2329071                    48.274
# 2329072                    48.274
# 2329073                    48.274

# %% [markdown]
# # Stores

# %%
df_stores = pd.read_csv('data/stores.csv')
verify(df_stores)
# Out:
# (54, 5)
#    store_nbr           city                           state type  cluster
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
#     store_nbr       city       state type  cluster
# 49         50     Ambato  Tungurahua    A       14
# 50         51  Guayaquil      Guayas    A       17
# 51         52      Manta      Manabi    A       11
# 52         53      Manta      Manabi    D       13
# 53         54  El Carmen      Manabi    C        3

# %%
df = df.merge(df_stores, on='store_nbr', how='inner')
verify(df)
# Out:
# (2329074, 91)
#         date  store_nbr      family   sales  onpromotion  year  month  day  \
# 0 2014-01-17          1  AUTOMOTIVE     2.0            0  2014      1   17
# 1 2014-01-17          1   BABY CARE     0.0            0  2014      1   17
# 2 2014-01-17          1      BEAUTY     4.0            0  2014      1   17
# 3 2014-01-17          1   BEVERAGES  2085.0            0  2014      1   17
# 4 2014-01-17          1       BOOKS     0.0            0  2014      1   17
#
#    day_of_week  business_day  sales_store_family_lag16  \
# 0            4             0                       0.0
# 1            4             0                       0.0
# 2            4             0                       0.0
# 3            4             0                       0.0
# 4            4             0                       0.0
#
#    sales_store_family_lag17  sales_store_family_lag18  \
# 0                       2.0                       1.0
# 1                       0.0                       0.0
# 2                       1.0                       3.0
# 3                     840.0                    1001.0
# 4                       0.0                       0.0
#
#    sales_store_family_lag19  sales_store_family_lag20  \
# 0                       0.0                       4.0
# 1                       0.0                       0.0
# 2                       0.0                       2.0
# 3                     242.0                     803.0
# 4                       0.0                       0.0
#
#    sales_store_family_lag21  sales_store_family_lag22  \
# 0                       6.0                       2.0
# 1                       0.0                       0.0
# 2                       0.0                       5.0
# 3                    1025.0                    1009.0
# 4                       0.0                       0.0
#
#    sales_store_family_lag30  sales_store_family_lag60  \
# 0                       1.0                       1.0
# 1                       0.0                       0.0
# 2                       0.0                       4.0
# 3                    1122.0                     901.0
# 4                       0.0                       0.0
#
#    sales_store_family_lag90  sales_store_family_lag120  \
# 0                       1.0                        2.0
# 1                       0.0                        0.0
# 2                       3.0                        0.0
# 3                     981.0                      848.0
# 4                       0.0                        0.0
#
#    sales_store_family_lag150  sales_store_family_lag180  \
# 0                        1.0                        1.0
# 1                        0.0                        0.0
# 2                        2.0                        1.0
# 3                      721.0                      279.0
# 4                        0.0                        0.0
#
#    sales_store_family_lag210  sales_store_family_lag240  \
# 0                        5.0                        1.0
# 1                        0.0                        0.0
# 2                        0.0                        3.0
# 3                      901.0                      871.0
# 4                        0.0                        0.0
#
#    sales_store_family_lag270  sales_store_family_lag300  \
# 0                        2.0                        0.0
# 1                        0.0                        0.0
# 2                        1.0                        1.0
# 3                      853.0                      985.0
# 4                        0.0                        0.0
#
#    sales_store_family_lag330  sales_store_family_lag360  \
# 0                        1.0                        1.0
# 1                        0.0                        0.0
# 2                        4.0                        1.0
# 3                      910.0                     1037.0
# 4                        0.0                        0.0
#
#    ema_sales_store_family_lag_16_22  ema_sales_store_family_lag_16_45  \
# 0                          1.474098                          1.833333
# 1                          0.000000                          0.000000
# 2                          1.238050                          1.500000
# 3                        652.122980                        942.233333
# 4                          0.000000                          0.000000
#
#    ema_sales_store_family_lag_16_380  sales_store_lag16  sales_store_lag17  \
# 0                           2.142466                0.0           4618.153
# 1                           0.000000                0.0           4618.153
# 2                           1.780822                0.0           4618.153
# 3                         858.071233                0.0           4618.153
# 4                           0.000000                0.0           4618.153
#
#    sales_store_lag18  sales_store_lag19  sales_store_lag20  sales_store_lag21  \
# 0         5754.39498        1819.251996           4532.439           7440.179
# 1         5754.39498        1819.251996           4532.439           7440.179
# 2         5754.39498        1819.251996           4532.439           7440.179
# 3         5754.39498        1819.251996           4532.439           7440.179
# 4         5754.39498        1819.251996           4532.439           7440.179
#
#    sales_store_lag22  sales_store_lag30  sales_store_lag60  sales_store_lag90  \
# 0           6151.595         9382.83803         6396.04003         5723.31102
# 1           6151.595         9382.83803         6396.04003         5723.31102
# 2           6151.595         9382.83803         6396.04003         5723.31102
# 3           6151.595         9382.83803         6396.04003         5723.31102
# 4           6151.595         9382.83803         6396.04003         5723.31102
#
#    sales_store_lag120  sales_store_lag150  sales_store_lag180  \
# 0          5064.11799         4658.069996             1905.67
# 1          5064.11799         4658.069996             1905.67
# 2          5064.11799         4658.069996             1905.67
# 3          5064.11799         4658.069996             1905.67
# 4          5064.11799         4658.069996             1905.67
#
#    sales_store_lag210  sales_store_lag240  sales_store_lag270  \
# 0            5608.436            5896.853            5504.771
# 1            5608.436            5896.853            5504.771
# 2            5608.436            5896.853            5504.771
# 3            5608.436            5896.853            5504.771
# 4            5608.436            5896.853            5504.771
#
#    sales_store_lag300  sales_store_lag330  sales_store_lag360  \
# 0            5518.596            5325.731            5298.986
# 1            5518.596            5325.731            5298.986
# 2            5518.596            5325.731            5298.986
# 3            5518.596            5325.731            5298.986
# 4            5518.596            5325.731            5298.986
#
#    ema_sales_store_lag_16_22  ema_sales_store_lag_16_45  \
# 0                4082.077424                6532.610967
# 1                4082.077424                6532.610967
# 2                4082.077424                6532.610967
# 3                4082.077424                6532.610967
# 4                4082.077424                6532.610967
#
#    ema_sales_store_lag_16_380  sales_family_lag16  sales_family_lag17  \
# 0                 5214.379628                 4.0               239.0
# 1                 5214.379628                 0.0                 0.0
# 2                 5214.379628                 2.0               107.0
# 3                 5214.379628              2175.0             92017.0
# 4                 5214.379628                 0.0                 0.0
#
#    sales_family_lag18  sales_family_lag19  sales_family_lag20  \
# 0               389.0               386.0               432.0
# 1                 0.0                 0.0                 0.0
# 2               163.0               161.0               198.0
# 3             96102.0             78396.0             88614.0
# 4                 0.0                 0.0                 0.0
#
#    sales_family_lag21  sales_family_lag22  sales_family_lag30  \
# 0               297.0               317.0               198.0
# 1                 0.0                 0.0                 0.0
# 2               143.0               169.0               102.0
# 3             77409.0             73168.0             63989.0
# 4                 0.0                 0.0                 0.0
#
#    sales_family_lag60  sales_family_lag90  sales_family_lag120  \
# 0               200.0               329.0                159.0
# 1                 0.0                 0.0                  0.0
# 2               101.0               197.0                 88.0
# 3             56867.0             80806.0              43939.0
# 4                 0.0                 0.0                  0.0
#
#    sales_family_lag150  sales_family_lag180  sales_family_lag210  \
# 0                224.0                364.0                206.0
# 1                  0.0                  0.0                  0.0
# 2                134.0                195.0                 84.0
# 3              50801.0              69215.0              50770.0
# 4                  0.0                  0.0                  0.0
#
#    sales_family_lag240  sales_family_lag270  sales_family_lag300  \
# 0                284.0                206.0                344.0
# 1                  0.0                  0.0                  0.0
# 2                104.0                104.0                132.0
# 3              47331.0              47858.0              75968.0
# 4                  0.0                  0.0                  0.0
#
#    sales_family_lag330  sales_family_lag360  ema_sales_family_lag_16_22  \
# 0                164.0                163.0                  242.154764
# 1                  0.0                  0.0                    0.000000
# 2                 96.0                106.0                  113.078043
# 3              41292.0              42931.0                65460.067410
# 4                  0.0                  0.0                    0.000000
#
#    ema_sales_family_lag_16_45  ema_sales_family_lag_16_380  dcoilwtico  \
# 0                  264.933333                   253.635616       93.96
# 1                    0.000000                     0.000000       93.96
# 2                  132.666667                   130.208219       93.96
# 3                71811.233333                 59902.942466       93.96
# 4                    0.000000                     0.000000       93.96
#
#    dcoilwtico_lag1  dcoilwtico_lag2  dcoilwtico_lag3  dcoilwtico_lag4  \
# 0            93.54            93.78            92.15            91.45
# 1            93.54            93.78            92.15            91.45
# 2            93.54            93.78            92.15            91.45
# 3            93.54            93.78            92.15            91.45
# 4            93.54            93.78            92.15            91.45
#
#    dcoilwtico_lag5  dcoilwtico_lag6  dcoilwtico_lag7  ema_dcoilwtico_lag_1_7  \
# 0            92.39            92.39            92.39               92.915199
# 1            92.39            92.39            92.39               92.915199
# 2            92.39            92.39            92.39               92.915199
# 3            92.39            92.39            92.39               92.915199
# 4            92.39            92.39            92.39               92.915199
#
#    ema_dcoilwtico_lag_1_30  ema_dcoilwtico_lag_1_365   city      state type  \
# 0                95.927333                 95.927333  Quito  Pichincha    D
# 1                95.927333                 95.927333  Quito  Pichincha    D
# 2                95.927333                 95.927333  Quito  Pichincha    D
# 3                95.927333                 95.927333  Quito  Pichincha    D
# 4                95.927333                 95.927333  Quito  Pichincha    D
#
#    cluster
# 0       13
# 1       13
# 2       13
# 3       13
# 4       13
#               date  store_nbr                      family    sales  \
# 2329069 2017-08-15         54                     POULTRY   59.619
# 2329070 2017-08-15         54              PREPARED FOODS   94.000
# 2329071 2017-08-15         54                     PRODUCE  915.371
# 2329072 2017-08-15         54  SCHOOL AND OFFICE SUPPLIES    0.000
# 2329073 2017-08-15         54                     SEAFOOD    3.000
#
#          onpromotion  year  month  day  day_of_week  business_day  \
# 2329069            0  2017      8   15            1             0
# 2329070            0  2017      8   15            1             0
# 2329071           76  2017      8   15            1             0
# 2329072            0  2017      8   15            1             0
# 2329073            0  2017      8   15            1             0
#
#          sales_store_family_lag16  sales_store_family_lag17  \
# 2329069                 72.895996                    82.296
# 2329070                124.000000                    81.000
# 2329071                793.147000                   729.844
# 2329072                  0.000000                     0.000
# 2329073                  4.000000                     4.000
#
#          sales_store_family_lag18  sales_store_family_lag19  \
# 2329069                    46.656                    52.086
# 2329070                    68.000                    73.000
# 2329071                   562.097                   520.489
# 2329072                     0.000                     0.000
# 2329073                     4.000                     2.000
#
#          sales_store_family_lag20  sales_store_family_lag21  \
# 2329069                    34.856                    50.686
# 2329070                    81.000                    65.000
# 2329071                   559.658                   914.959
# 2329072                     0.000                     0.000
# 2329073                     3.000                     7.000
#
#          sales_store_family_lag22  sales_store_family_lag30  \
# 2329069                    51.209                   103.902
# 2329070                   112.000                    50.000
# 2329071                   654.930                   981.712
# 2329072                     0.000                     0.000
# 2329073                     1.000                     5.000
#
#          sales_store_family_lag60  sales_store_family_lag90  \
# 2329069                    72.770                    44.233
# 2329070                    79.000                    81.000
# 2329071                   580.389                   506.987
# 2329072                     0.000                     1.000
# 2329073                     2.000                     2.000
#
#          sales_store_family_lag120  sales_store_family_lag150  \
# 2329069                     56.169                     47.291
# 2329070                     29.000                     70.000
# 2329071                    559.538                    659.408
# 2329072                      1.000                      0.000
# 2329073                      0.000                      3.000
#
#          sales_store_family_lag180  sales_store_family_lag210  \
# 2329069                     46.572                     57.161
# 2329070                     49.000                     98.000
# 2329071                    426.046                    862.417
# 2329072                      0.000                      0.000
# 2329073                      1.000                      2.000
#
#          sales_store_family_lag240  sales_store_family_lag270  \
# 2329069                     66.212                     91.916
# 2329070                    103.000                     74.000
# 2329071                    816.129                    613.487
# 2329072                      0.000                      0.000
# 2329073                      5.000                      0.000
#
#          sales_store_family_lag300  sales_store_family_lag330  \
# 2329069                     34.801                  49.364998
# 2329070                     70.000                  80.000000
# 2329071                    555.718                 549.655000
# 2329072                      0.000                   0.000000
# 2329073                      0.000                   0.000000
#
#          sales_store_family_lag360  ema_sales_store_family_lag_16_22  \
# 2329069                     29.669                      6.453319e+01
# 2329070                     52.000                      9.153548e+01
# 2329071                    713.194                      6.889917e+02
# 2329072                      0.000                      2.320649e-09
# 2329073                      2.000                      3.621519e+00
#
#          ema_sales_store_family_lag_16_45  ema_sales_store_family_lag_16_380  \
# 2329069                         69.364066                          62.222482
# 2329070                         85.000000                          75.816438
# 2329071                        698.255533                         655.923181
# 2329072                          0.000000                           1.679452
# 2329073                          3.100000                           1.967123
#
#          sales_store_lag16  sales_store_lag17  sales_store_lag18  \
# 2329069       15815.709996          10878.746        9531.089998
# 2329070       15815.709996          10878.746        9531.089998
# 2329071       15815.709996          10878.746        9531.089998
# 2329072       15815.709996          10878.746        9531.089998
# 2329073       15815.709996          10878.746        9531.089998
#
#          sales_store_lag19  sales_store_lag20  sales_store_lag21  \
# 2329069           6911.345           6572.494           8241.906
# 2329070           6911.345           6572.494           8241.906
# 2329071           6911.345           6572.494           8241.906
# 2329072           6911.345           6572.494           8241.906
# 2329073           6911.345           6572.494           8241.906
#
#          sales_store_lag22  sales_store_lag30  sales_store_lag60  \
# 2329069       10245.246998          16959.135       10540.249999
# 2329070       10245.246998          16959.135       10540.249999
# 2329071       10245.246998          16959.135       10540.249999
# 2329072       10245.246998          16959.135       10540.249999
# 2329073       10245.246998          16959.135       10540.249999
#
#          sales_store_lag90  sales_store_lag120  sales_store_lag150  \
# 2329069          17721.085            8402.924           10604.055
# 2329070          17721.085            8402.924           10604.055
# 2329071          17721.085            8402.924           10604.055
# 2329072          17721.085            8402.924           10604.055
# 2329073          17721.085            8402.924           10604.055
#
#          sales_store_lag180  sales_store_lag210  sales_store_lag240  \
# 2329069            5518.609            7374.671           12540.281
# 2329070            5518.609            7374.671           12540.281
# 2329071            5518.609            7374.671           12540.281
# 2329072            5518.609            7374.671           12540.281
# 2329073            5518.609            7374.671           12540.281
#
#          sales_store_lag270  sales_store_lag300  sales_store_lag330  \
# 2329069         5940.149002            6340.114         8185.356998
# 2329070         5940.149002            6340.114         8185.356998
# 2329071         5940.149002            6340.114         8185.356998
# 2329072         5940.149002            6340.114         8185.356998
# 2329073         5940.149002            6340.114         8185.356998
#
#          sales_store_lag360  ema_sales_store_lag_16_22  \
# 2329069            8424.711               11041.179674
# 2329070            8424.711               11041.179674
# 2329071            8424.711               11041.179674
# 2329072            8424.711               11041.179674
# 2329073            8424.711               11041.179674
#
#          ema_sales_store_lag_16_45  ema_sales_store_lag_16_380  \
# 2329069                 10163.7067                 8816.963789
# 2329070                 10163.7067                 8816.963789
# 2329071                 10163.7067                 8816.963789
# 2329072                 10163.7067                 8816.963789
# 2329073                 10163.7067                 8816.963789
#
#          sales_family_lag16  sales_family_lag17  sales_family_lag18  \
# 2329069        25089.244942        22477.071865        28521.282225
# 2329070         5507.523005         5408.918016         4722.614983
# 2329071       146045.795000       131988.661970       111948.890000
# 2329072         2027.000000         1345.000000          567.000000
# 2329073         1379.617003         1297.514006         1307.945999
#
#          sales_family_lag19  sales_family_lag20  sales_family_lag21  \
# 2329069        14552.290992        16548.687010        16769.651937
# 2329070         4168.786016         4456.418986         4129.020989
# 2329071        90481.286100       145917.919100       115457.658700
# 2329072          244.000000          166.000000          174.000000
# 2329073          652.069999          839.655002          842.090999
#
#          sales_family_lag22  sales_family_lag30  sales_family_lag60  \
# 2329069        19464.661030        26360.768010        31804.989046
# 2329070         4823.321997         5534.052983         5001.446010
# 2329071       117117.095010       157883.056000       124173.953500
# 2329072          192.000000          121.000000           58.000000
# 2329073          995.327001         1413.877000         1315.639001
#
#          sales_family_lag90  sales_family_lag120  sales_family_lag150  \
# 2329069         18491.03000         17711.450004         23457.777090
# 2329070          4738.09202          4342.841024          7189.561030
# 2329071        166802.77490        115072.020880        139267.040030
# 2329072           215.00000           718.000000           150.000000
# 2329073          1195.40500           998.932001          1597.305998
#
#          sales_family_lag180  sales_family_lag210  sales_family_lag240  \
# 2329069         16029.954000         17694.390035         26878.779050
# 2329070          5153.443006          5341.388989          7448.360985
# 2329071         95892.378030        124250.204900        155663.954600
# 2329072            60.000000            80.000000           129.000000
# 2329073           858.070005           990.695003          1289.671995
#
#          sales_family_lag270  sales_family_lag300  sales_family_lag330  \
# 2329069         28038.540014         15365.961035         16143.457978
# 2329070          5268.237992          4946.688980          5305.362987
# 2329071        102969.517830        138579.652000        104423.301000
# 2329072            71.000000            69.000000           146.000000
# 2329073          1362.009002          1080.609002          1138.018999
#
#          sales_family_lag360  ema_sales_family_lag_16_22  \
# 2329069         21158.702034                22225.768154
# 2329070          6106.435004                 4968.954790
# 2329071        120558.737800               127348.465736
# 2329072           787.000000                  925.102321
# 2329073          1447.197998                 1155.706294
#
#          ema_sales_family_lag_16_45  ema_sales_family_lag_16_380  dcoilwtico  \
# 2329069                21734.075462                 21059.267403       47.57
# 2329070                 4894.940064                  5550.034376       47.57
# 2329071               129450.195936                125742.800885       47.57
# 2329072                  239.033333                   300.334247       47.57
# 2329073                 1131.143900                  1213.799340       47.57
#
#          dcoilwtico_lag1  dcoilwtico_lag2  dcoilwtico_lag3  dcoilwtico_lag4  \
# 2329069            47.59            48.81            48.81            48.81
# 2329070            47.59            48.81            48.81            48.81
# 2329071            47.59            48.81            48.81            48.81
# 2329072            47.59            48.81            48.81            48.81
# 2329073            47.59            48.81            48.81            48.81
#
#          dcoilwtico_lag5  dcoilwtico_lag6  dcoilwtico_lag7  \
# 2329069            48.54            49.59            49.07
# 2329070            48.54            49.59            49.07
# 2329071            48.54            49.59            49.07
# 2329072            48.54            49.59            49.07
# 2329073            48.54            49.59            49.07
#
#          ema_dcoilwtico_lag_1_7  ema_dcoilwtico_lag_1_30  \
# 2329069                48.62108                   48.274
# 2329070                48.62108                   48.274
# 2329071                48.62108                   48.274
# 2329072                48.62108                   48.274
# 2329073                48.62108                   48.274
#
#          ema_dcoilwtico_lag_1_365       city   state type  cluster
# 2329069                    48.274  El Carmen  Manabi    C        3
# 2329070                    48.274  El Carmen  Manabi    C        3
# 2329071                    48.274  El Carmen  Manabi    C        3
# 2329072                    48.274  El Carmen  Manabi    C        3
# 2329073                    48.274  El Carmen  Manabi    C        3

# %% [markdown]
# # Holidays Events

# %%
df_holidays = pd.read_csv('data/holidays_events.csv')
verify(df_holidays)
# Out:
# (350, 6)
#          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3  2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4  2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#            date        type    locale locale_name description  transferred
# 345  2017-12-22  Additional  National     Ecuador   Navidad-3        False
# 346  2017-12-23  Additional  National     Ecuador   Navidad-2        False
# 347  2017-12-24  Additional  National     Ecuador   Navidad-1        False
# 348  2017-12-25     Holiday  National     Ecuador     Navidad        False
# 349  2017-12-26  Additional  National     Ecuador   Navidad+1        False

# %%
df_holidays['date'] = pd.to_datetime(df_holidays['date'])
df_holidays = df_holidays[df_holidays['transferred'] == False]
df_holidays.shape
# Out:
# (338, 6)

# %%
df_holidays.type.unique()
# Out:
# array(['Holiday', 'Transfer', 'Additional', 'Bridge', 'Work Day', 'Event'],
#       dtype=object)

# %%
day_off = df_holidays[(df_holidays['locale'] == 'National') & 
                      (df_holidays['type'].isin(['Transfer', 'Additional', 'Bridge']))].date.unique()
df['national_holiday'] = [1 if date in day_off else 0 for date in df.date]
df.national_holiday.value_counts()
# Out:
# 0    2275614
# 1      53460
# Name: national_holiday, dtype: int64

# %%
event = df_holidays[(df_holidays['locale'] == 'National') & 
                    (df_holidays['type'] == 'Event')].date.unique()
df['national_event'] = [1 if date in event else 0 for date in df.date]
df.national_event.value_counts()
# Out:
# 0    2232846
# 1      96228
# Name: national_event, dtype: int64

# %%
print(set(df_holidays.locale_name) & set(df.city))

dates_local_holidays = df_holidays[(df_holidays['locale'] == 'Local')].set_index('date').locale_name.to_dict()
df['local_holiday'] = [1 if date in dates_local_holidays and dates_local_holidays[date]== city else 0 for city,date in zip(df.city,df.date)]
df.local_holiday.value_counts()
# Out:
# {'El Carmen', 'Puyo', 'Guaranda', 'Salinas', 'Quevedo', 'Loja', 'Ibarra', 'Cuenca', 'Esmeraldas', 'Cayambe', 'Manta', 'Riobamba', 'Quito', 'Ambato', 'Machala', 'Santo Domingo', 'Guayaquil', 'Libertad', 'Latacunga'}
# 0    2320329
# 1       8745
# Name: local_holiday, dtype: int64

# %%
print(set(df_holidays.locale_name) & set(df.state))

dates_regional_holidays = df_holidays[(df_holidays['locale'] == 'Regional')].set_index('date').locale_name.to_dict()
df['regional_holiday'] = [1 if date in dates_regional_holidays and dates_regional_holidays[date]== state else 0 for state,date in zip(df.state,df.date)]
df.regional_holiday.value_counts()
# Out:
# {'Santa Elena', 'Santo Domingo de los Tsachilas', 'Esmeraldas', 'Loja', 'Imbabura', 'Cotopaxi'}
# 0    2328282
# 1        792
# Name: regional_holiday, dtype: int64

# %% [markdown]
# # Transactions

# %%
df_transactions = pd.read_csv('data/transactions_clean.csv')
verify(df_transactions)
# Out:
# (91152, 3)
#          date  store_nbr  transactions
# 0  2013-01-01       25.0         770.0
# 1  2013-01-02       25.0        1038.0
# 2  2013-01-03       25.0         887.0
# 3  2013-01-04       25.0        1054.0
# 4  2013-01-05       25.0        1355.0
#              date  store_nbr  transactions
# 91147  2017-08-11       52.0        2957.0
# 91148  2017-08-12       52.0        2804.0
# 91149  2017-08-13       52.0        2433.0
# 91150  2017-08-14       52.0        2074.0
# 91151  2017-08-15       52.0        2255.0

# %%
df_transactions['date'] = pd.to_datetime(df_transactions['date'])
df_transactions = df_transactions[df_transactions['date'] >= pd.to_datetime('2013-01-02')]

# %%
df_stores = df_transactions.copy()
df_stores = df_stores.sort_values(['store_nbr', 'date']).reset_index(drop=True)

cols_week = []
for lag in list(range(16,23)):
    df_stores[f'transactions_store_lag{lag}'] = df_stores.groupby(['store_nbr']).transactions.shift(lag)
    cols_week.append(f'transactions_store_lag{lag}')

cols_year = []
for lag in list(range(30,361,30)):
    df_stores[f'transactions_store_lag{lag}'] = df_stores.groupby(['store_nbr']).transactions.shift(lag)
    cols_year.append(f'transactions_store_lag{lag}')

df_stores['ema_transactions_store_week'] = df_stores.groupby(['store_nbr']).transactions.ewm(span=7, adjust=False, min_periods=7).mean().reset_index(drop=True)
df_stores['ema_transactions_store_lag_16_22'] = df_stores.groupby(['store_nbr']).ema_transactions_store_week.shift(16)

df_stores['ema_transactions_store_month'] = df_stores.groupby(['store_nbr']).transactions.rolling(30, min_periods=30).mean().reset_index(drop=True)
df_stores['ema_transactions_store_lag_16_45'] = df_stores.groupby(['store_nbr']).ema_transactions_store_month.shift(16)

df_stores['ema_transactions_store_year'] = df_stores.groupby(['store_nbr']).transactions.rolling(365, min_periods=365).mean().reset_index(drop=True)
df_stores['ema_transactions_store_lag_16_380'] = df_stores.groupby(['store_nbr']).ema_transactions_store_year.shift(16)

df_stores.drop(columns=['ema_transactions_store_week', 'ema_transactions_store_month', 'ema_transactions_store_year', 
                        'transactions'], 
        inplace=True)

verify(df_stores)
print(df_stores[[i for i in df_stores.columns if 'transactions_store_lag' in i]].isna().sum())
# Out:
# (91098, 24)
#         date  store_nbr  transactions_store_lag16  transactions_store_lag17  \
# 0 2013-01-02        1.0                       NaN                       NaN
# 1 2013-01-03        1.0                       NaN                       NaN
# 2 2013-01-04        1.0                       NaN                       NaN
# 3 2013-01-05        1.0                       NaN                       NaN
# 4 2013-01-06        1.0                       NaN                       NaN
#
#    transactions_store_lag18  transactions_store_lag19  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    transactions_store_lag20  transactions_store_lag21  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    transactions_store_lag22  transactions_store_lag30  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    transactions_store_lag60  transactions_store_lag90  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    transactions_store_lag120  transactions_store_lag150  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    transactions_store_lag180  transactions_store_lag210  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    transactions_store_lag240  transactions_store_lag270  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    transactions_store_lag300  transactions_store_lag330  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    transactions_store_lag360  ema_transactions_store_lag_16_22  \
# 0                        NaN                               NaN
# 1                        NaN                               NaN
# 2                        NaN                               NaN
# 3                        NaN                               NaN
# 4                        NaN                               NaN
#
#    ema_transactions_store_lag_16_45  ema_transactions_store_lag_16_380
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#             date  store_nbr  transactions_store_lag16  \
# 91093 2017-08-11       54.0                     700.0
# 91094 2017-08-12       54.0                     662.0
# 91095 2017-08-13       54.0                     766.0
# 91096 2017-08-14       54.0                     870.0
# 91097 2017-08-15       54.0                    1108.0
#
#        transactions_store_lag17  transactions_store_lag18  \
# 91093                     727.0                     792.0
# 91094                     700.0                     727.0
# 91095                     662.0                     700.0
# 91096                     766.0                     662.0
# 91097                     870.0                     766.0
#
#        transactions_store_lag19  transactions_store_lag20  \
# 91093                     926.0                     876.0
# 91094                     792.0                     926.0
# 91095                     727.0                     792.0
# 91096                     700.0                     727.0
# 91097                     662.0                     700.0
#
#        transactions_store_lag21  transactions_store_lag22  \
# 91093                     676.0                     647.0
# 91094                     876.0                     676.0
# 91095                     926.0                     876.0
# 91096                     792.0                     926.0
# 91097                     727.0                     792.0
#
#        transactions_store_lag30  transactions_store_lag60  \
# 91093                     692.0                     781.0
# 91094                     683.0                     770.0
# 91095                     676.0                     731.0
# 91096                     855.0                     672.0
# 91097                     920.0                     754.0
#
#        transactions_store_lag90  transactions_store_lag120  \
# 91093                    1112.0                      826.0
# 91094                    1212.0                      834.0
# 91095                     884.0                      898.0
# 91096                     841.0                      976.0
# 91097                     706.0                      724.0
#
#        transactions_store_lag150  transactions_store_lag180  \
# 91093                      699.0                     1073.0
# 91094                      800.0                      886.0
# 91095                      613.0                     1035.0
# 91096                      787.0                      742.0
# 91097                      968.0                      662.0
#
#        transactions_store_lag210  transactions_store_lag240  \
# 91093                      766.0                      746.0
# 91094                      958.0                      729.0
# 91095                     1029.0                      862.0
# 91096                      904.0                      984.0
# 91097                      745.0                     1165.0
#
#        transactions_store_lag270  transactions_store_lag300  \
# 91093                      832.0                      927.0
# 91094                      798.0                     1142.0
# 91095                      741.0                      806.0
# 91096                      705.0                      778.0
# 91097                      714.0                      678.0
#
#        transactions_store_lag330  transactions_store_lag360  \
# 91093                      712.0                      804.0
# 91094                      778.0                      679.0
# 91095                      954.0                      709.0
# 91096                     1091.0                      752.0
# 91097                      847.0                      916.0
#
#        ema_transactions_store_lag_16_22  ema_transactions_store_lag_16_45  \
# 91093                        761.164081                        788.733333
# 91094                        736.373061                        785.233333
# 91095                        743.779796                        788.700000
# 91096                        775.334847                        793.800000
# 91097                        858.501135                        807.233333
#
#        ema_transactions_store_lag_16_380
# 91093                         829.961644
# 91094                         829.821918
# 91095                         830.079452
# 91096                         830.383562
# 91097                         830.684932
# transactions_store_lag16               864
# transactions_store_lag17               918
# transactions_store_lag18               972
# transactions_store_lag19              1026
# transactions_store_lag20              1080
# transactions_store_lag21              1134
# transactions_store_lag22              1188
# transactions_store_lag30              1620
# transactions_store_lag60              3240
# transactions_store_lag90              4860
# transactions_store_lag120             6480
# transactions_store_lag150             8100
# transactions_store_lag180             9720
# transactions_store_lag210            11340
# transactions_store_lag240            12960
# transactions_store_lag270            14580
# transactions_store_lag300            16200
# transactions_store_lag330            17820
# transactions_store_lag360            19440
# ema_transactions_store_lag_16_22      1188
# ema_transactions_store_lag_16_45      2430
# ema_transactions_store_lag_16_380    20520
# dtype: int64

# %%
df_transactions = df_transactions.groupby("date").transactions.sum().reset_index()

cols_week = []
for lag in list(range(16,23)):
    df_transactions[f'transactions_lag{lag}'] = df_transactions.transactions.shift(lag)
    cols_week.append(f'transactions_lag{lag}')

cols_year = []
for lag in list(range(30,361,30)):
    df_transactions[f'transactions_lag{lag}'] = df_transactions.transactions.shift(lag)
    cols_year.append(f'transactions_lag{lag}')

df_transactions['ema_transactions_week'] = df_transactions.transactions.ewm(span=7, adjust=False, min_periods=7).mean().reset_index(drop=True)
df_transactions['ema_transactions_lag_16_22'] = df_transactions.ema_transactions_week.shift(16)

df_transactions['ema_transactions_month'] = df_transactions.transactions.rolling(30, min_periods=30).mean().reset_index(drop=True)
df_transactions['ema_transactions_lag_16_45'] = df_transactions.ema_transactions_month.shift(16)

df_transactions['ema_transactions_year'] = df_transactions.transactions.rolling(365, min_periods=365).mean().reset_index(drop=True)
df_transactions['ema_transactions_lag_16_380'] = df_transactions.ema_transactions_year.shift(16)

df_transactions.drop(columns=['ema_transactions_week', 'ema_transactions_month', 'ema_transactions_year',
                              'transactions'], 
        inplace=True)

verify(df_transactions)
print(df_transactions[[i for i in df_transactions.columns if 'transactions_lag' in i]].isna().sum())
# Out:
# (1687, 23)
#         date  transactions_lag16  transactions_lag17  transactions_lag18  \
# 0 2013-01-02                 NaN                 NaN                 NaN
# 1 2013-01-03                 NaN                 NaN                 NaN
# 2 2013-01-04                 NaN                 NaN                 NaN
# 3 2013-01-05                 NaN                 NaN                 NaN
# 4 2013-01-06                 NaN                 NaN                 NaN
#
#    transactions_lag19  transactions_lag20  transactions_lag21  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    transactions_lag22  transactions_lag30  transactions_lag60  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    transactions_lag90  transactions_lag120  transactions_lag150  \
# 0                 NaN                  NaN                  NaN
# 1                 NaN                  NaN                  NaN
# 2                 NaN                  NaN                  NaN
# 3                 NaN                  NaN                  NaN
# 4                 NaN                  NaN                  NaN
#
#    transactions_lag180  transactions_lag210  transactions_lag240  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    transactions_lag270  transactions_lag300  transactions_lag330  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    transactions_lag360  ema_transactions_lag_16_22  \
# 0                  NaN                         NaN
# 1                  NaN                         NaN
# 2                  NaN                         NaN
# 3                  NaN                         NaN
# 4                  NaN                         NaN
#
#    ema_transactions_lag_16_45  ema_transactions_lag_16_380
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#            date  transactions_lag16  transactions_lag17  transactions_lag18  \
# 1682 2017-08-11             82113.0             81930.0             85120.0
# 1683 2017-08-12             78743.0             82113.0             81930.0
# 1684 2017-08-13             89197.0             78743.0             82113.0
# 1685 2017-08-14            100227.0             89197.0             78743.0
# 1686 2017-08-15             94899.0            100227.0             89197.0
#
#       transactions_lag19  transactions_lag20  transactions_lag21  \
# 1682             94170.0             97358.0             88613.0
# 1683             85120.0             94170.0             97358.0
# 1684             81930.0             85120.0             94170.0
# 1685             82113.0             81930.0             85120.0
# 1686             78743.0             82113.0             81930.0
#
#       transactions_lag22  transactions_lag30  transactions_lag60  \
# 1682             82423.0             84155.0             81080.0
# 1683             88613.0             78720.0             81063.0
# 1684             97358.0             87671.0             82752.0
# 1685             94170.0            100293.0             81831.0
# 1686             85120.0             96119.0             92852.0
#
#       transactions_lag90  transactions_lag120  transactions_lag150  \
# 1682            121889.0              90752.0              78200.0
# 1683            101257.0              86517.0              84574.0
# 1684             83716.0              97165.0              79030.0
# 1685             85528.0              90664.0              87303.0
# 1686             85560.0              83043.0              99094.0
#
#       transactions_lag180  transactions_lag210  transactions_lag240  \
# 1682              93429.0              84068.0              89417.0
# 1683              93688.0              99921.0              91525.0
# 1684              99371.0              97107.0              99717.0
# 1685              80501.0              84038.0             114465.0
# 1686              77887.0              80093.0             116289.0
#
#       transactions_lag270  transactions_lag300  transactions_lag330  \
# 1682              77317.0              92768.0              74741.0
# 1683              76651.0              93951.0              80789.0
# 1684              81603.0              76614.0              94298.0
# 1685              74999.0              73632.0              92375.0
# 1686              81854.0              72931.0              76255.0
#
#       transactions_lag360  ema_transactions_lag_16_22  \
# 1682              81063.0                86004.902876
# 1683              81405.0                84189.427157
# 1684              75159.0                85441.320368
# 1685              82021.0                89137.740276
# 1686              91798.0                90578.055207
#
#       ema_transactions_lag_16_45  ema_transactions_lag_16_380
# 1682                88614.466667                 87278.339726
# 1683                88598.366667                 87281.112329
# 1684                88886.566667                 87328.405479
# 1685                89630.066667                 87377.958904
# 1686                89847.766667                 87374.260274
# transactions_lag16              16
# transactions_lag17              17
# transactions_lag18              18
# transactions_lag19              19
# transactions_lag20              20
# transactions_lag21              21
# transactions_lag22              22
# transactions_lag30              30
# transactions_lag60              60
# transactions_lag90              90
# transactions_lag120            120
# transactions_lag150            150
# transactions_lag180            180
# transactions_lag210            210
# transactions_lag240            240
# transactions_lag270            270
# transactions_lag300            300
# transactions_lag330            330
# transactions_lag360            360
# ema_transactions_lag_16_22      22
# ema_transactions_lag_16_45      45
# ema_transactions_lag_16_380    380
# dtype: int64

# %%
df = df.merge(df_stores, on=['date', 'store_nbr'], how='inner')
del df_stores

df = df.merge(df_transactions, on=['date'], how='inner')
del df_transactions

verify(df)
# Out:
# (2329074, 139)
#         date  store_nbr      family   sales  onpromotion  year  month  day  \
# 0 2014-01-17          1  AUTOMOTIVE     2.0            0  2014      1   17
# 1 2014-01-17          1   BABY CARE     0.0            0  2014      1   17
# 2 2014-01-17          1      BEAUTY     4.0            0  2014      1   17
# 3 2014-01-17          1   BEVERAGES  2085.0            0  2014      1   17
# 4 2014-01-17          1       BOOKS     0.0            0  2014      1   17
#
#    day_of_week  business_day  sales_store_family_lag16  \
# 0            4             0                       0.0
# 1            4             0                       0.0
# 2            4             0                       0.0
# 3            4             0                       0.0
# 4            4             0                       0.0
#
#    sales_store_family_lag17  sales_store_family_lag18  \
# 0                       2.0                       1.0
# 1                       0.0                       0.0
# 2                       1.0                       3.0
# 3                     840.0                    1001.0
# 4                       0.0                       0.0
#
#    sales_store_family_lag19  sales_store_family_lag20  \
# 0                       0.0                       4.0
# 1                       0.0                       0.0
# 2                       0.0                       2.0
# 3                     242.0                     803.0
# 4                       0.0                       0.0
#
#    sales_store_family_lag21  sales_store_family_lag22  \
# 0                       6.0                       2.0
# 1                       0.0                       0.0
# 2                       0.0                       5.0
# 3                    1025.0                    1009.0
# 4                       0.0                       0.0
#
#    sales_store_family_lag30  sales_store_family_lag60  \
# 0                       1.0                       1.0
# 1                       0.0                       0.0
# 2                       0.0                       4.0
# 3                    1122.0                     901.0
# 4                       0.0                       0.0
#
#    sales_store_family_lag90  sales_store_family_lag120  \
# 0                       1.0                        2.0
# 1                       0.0                        0.0
# 2                       3.0                        0.0
# 3                     981.0                      848.0
# 4                       0.0                        0.0
#
#    sales_store_family_lag150  sales_store_family_lag180  \
# 0                        1.0                        1.0
# 1                        0.0                        0.0
# 2                        2.0                        1.0
# 3                      721.0                      279.0
# 4                        0.0                        0.0
#
#    sales_store_family_lag210  sales_store_family_lag240  \
# 0                        5.0                        1.0
# 1                        0.0                        0.0
# 2                        0.0                        3.0
# 3                      901.0                      871.0
# 4                        0.0                        0.0
#
#    sales_store_family_lag270  sales_store_family_lag300  \
# 0                        2.0                        0.0
# 1                        0.0                        0.0
# 2                        1.0                        1.0
# 3                      853.0                      985.0
# 4                        0.0                        0.0
#
#    sales_store_family_lag330  sales_store_family_lag360  \
# 0                        1.0                        1.0
# 1                        0.0                        0.0
# 2                        4.0                        1.0
# 3                      910.0                     1037.0
# 4                        0.0                        0.0
#
#    ema_sales_store_family_lag_16_22  ema_sales_store_family_lag_16_45  \
# 0                          1.474098                          1.833333
# 1                          0.000000                          0.000000
# 2                          1.238050                          1.500000
# 3                        652.122980                        942.233333
# 4                          0.000000                          0.000000
#
#    ema_sales_store_family_lag_16_380  sales_store_lag16  sales_store_lag17  \
# 0                           2.142466                0.0           4618.153
# 1                           0.000000                0.0           4618.153
# 2                           1.780822                0.0           4618.153
# 3                         858.071233                0.0           4618.153
# 4                           0.000000                0.0           4618.153
#
#    sales_store_lag18  sales_store_lag19  sales_store_lag20  sales_store_lag21  \
# 0         5754.39498        1819.251996           4532.439           7440.179
# 1         5754.39498        1819.251996           4532.439           7440.179
# 2         5754.39498        1819.251996           4532.439           7440.179
# 3         5754.39498        1819.251996           4532.439           7440.179
# 4         5754.39498        1819.251996           4532.439           7440.179
#
#    sales_store_lag22  sales_store_lag30  sales_store_lag60  sales_store_lag90  \
# 0           6151.595         9382.83803         6396.04003         5723.31102
# 1           6151.595         9382.83803         6396.04003         5723.31102
# 2           6151.595         9382.83803         6396.04003         5723.31102
# 3           6151.595         9382.83803         6396.04003         5723.31102
# 4           6151.595         9382.83803         6396.04003         5723.31102
#
#    sales_store_lag120  sales_store_lag150  sales_store_lag180  \
# 0          5064.11799         4658.069996             1905.67
# 1          5064.11799         4658.069996             1905.67
# 2          5064.11799         4658.069996             1905.67
# 3          5064.11799         4658.069996             1905.67
# 4          5064.11799         4658.069996             1905.67
#
#    sales_store_lag210  sales_store_lag240  sales_store_lag270  \
# 0            5608.436            5896.853            5504.771
# 1            5608.436            5896.853            5504.771
# 2            5608.436            5896.853            5504.771
# 3            5608.436            5896.853            5504.771
# 4            5608.436            5896.853            5504.771
#
#    sales_store_lag300  sales_store_lag330  sales_store_lag360  \
# 0            5518.596            5325.731            5298.986
# 1            5518.596            5325.731            5298.986
# 2            5518.596            5325.731            5298.986
# 3            5518.596            5325.731            5298.986
# 4            5518.596            5325.731            5298.986
#
#    ema_sales_store_lag_16_22  ema_sales_store_lag_16_45  \
# 0                4082.077424                6532.610967
# 1                4082.077424                6532.610967
# 2                4082.077424                6532.610967
# 3                4082.077424                6532.610967
# 4                4082.077424                6532.610967
#
#    ema_sales_store_lag_16_380  sales_family_lag16  sales_family_lag17  \
# 0                 5214.379628                 4.0               239.0
# 1                 5214.379628                 0.0                 0.0
# 2                 5214.379628                 2.0               107.0
# 3                 5214.379628              2175.0             92017.0
# 4                 5214.379628                 0.0                 0.0
#
#    sales_family_lag18  sales_family_lag19  sales_family_lag20  \
# 0               389.0               386.0               432.0
# 1                 0.0                 0.0                 0.0
# 2               163.0               161.0               198.0
# 3             96102.0             78396.0             88614.0
# 4                 0.0                 0.0                 0.0
#
#    sales_family_lag21  sales_family_lag22  sales_family_lag30  \
# 0               297.0               317.0               198.0
# 1                 0.0                 0.0                 0.0
# 2               143.0               169.0               102.0
# 3             77409.0             73168.0             63989.0
# 4                 0.0                 0.0                 0.0
#
#    sales_family_lag60  sales_family_lag90  sales_family_lag120  \
# 0               200.0               329.0                159.0
# 1                 0.0                 0.0                  0.0
# 2               101.0               197.0                 88.0
# 3             56867.0             80806.0              43939.0
# 4                 0.0                 0.0                  0.0
#
#    sales_family_lag150  sales_family_lag180  sales_family_lag210  \
# 0                224.0                364.0                206.0
# 1                  0.0                  0.0                  0.0
# 2                134.0                195.0                 84.0
# 3              50801.0              69215.0              50770.0
# 4                  0.0                  0.0                  0.0
#
#    sales_family_lag240  sales_family_lag270  sales_family_lag300  \
# 0                284.0                206.0                344.0
# 1                  0.0                  0.0                  0.0
# 2                104.0                104.0                132.0
# 3              47331.0              47858.0              75968.0
# 4                  0.0                  0.0                  0.0
#
#    sales_family_lag330  sales_family_lag360  ema_sales_family_lag_16_22  \
# 0                164.0                163.0                  242.154764
# 1                  0.0                  0.0                    0.000000
# 2                 96.0                106.0                  113.078043
# 3              41292.0              42931.0                65460.067410
# 4                  0.0                  0.0                    0.000000
#
#    ema_sales_family_lag_16_45  ema_sales_family_lag_16_380  dcoilwtico  \
# 0                  264.933333                   253.635616       93.96
# 1                    0.000000                     0.000000       93.96
# 2                  132.666667                   130.208219       93.96
# 3                71811.233333                 59902.942466       93.96
# 4                    0.000000                     0.000000       93.96
#
#    dcoilwtico_lag1  dcoilwtico_lag2  dcoilwtico_lag3  dcoilwtico_lag4  \
# 0            93.54            93.78            92.15            91.45
# 1            93.54            93.78            92.15            91.45
# 2            93.54            93.78            92.15            91.45
# 3            93.54            93.78            92.15            91.45
# 4            93.54            93.78            92.15            91.45
#
#    dcoilwtico_lag5  dcoilwtico_lag6  dcoilwtico_lag7  ema_dcoilwtico_lag_1_7  \
# 0            92.39            92.39            92.39               92.915199
# 1            92.39            92.39            92.39               92.915199
# 2            92.39            92.39            92.39               92.915199
# 3            92.39            92.39            92.39               92.915199
# 4            92.39            92.39            92.39               92.915199
#
#    ema_dcoilwtico_lag_1_30  ema_dcoilwtico_lag_1_365   city      state type  \
# 0                95.927333                 95.927333  Quito  Pichincha    D
# 1                95.927333                 95.927333  Quito  Pichincha    D
# 2                95.927333                 95.927333  Quito  Pichincha    D
# 3                95.927333                 95.927333  Quito  Pichincha    D
# 4                95.927333                 95.927333  Quito  Pichincha    D
#
#    cluster  national_holiday  national_event  local_holiday  regional_holiday  \
# 0       13                 0               0              0                 0
# 1       13                 0               0              0                 0
# 2       13                 0               0              0                 0
# 3       13                 0               0              0                 0
# 4       13                 0               0              0                 0
#
#    transactions_store_lag16  transactions_store_lag17  \
# 0                       0.0                    1105.0
# 1                       0.0                    1105.0
# 2                       0.0                    1105.0
# 3                       0.0                    1105.0
# 4                       0.0                    1105.0
#
#    transactions_store_lag18  transactions_store_lag19  \
# 0                    1388.0                     416.0
# 1                    1388.0                     416.0
# 2                    1388.0                     416.0
# 3                    1388.0                     416.0
# 4                    1388.0                     416.0
#
#    transactions_store_lag20  transactions_store_lag21  \
# 0                    1070.0                    2022.0
# 1                    1070.0                    2022.0
# 2                    1070.0                    2022.0
# 3                    1070.0                    2022.0
# 4                    1070.0                    2022.0
#
#    transactions_store_lag22  transactions_store_lag30  \
# 0                    1980.0                    2337.0
# 1                    1980.0                    2337.0
# 2                    1980.0                    2337.0
# 3                    1980.0                    2337.0
# 4                    1980.0                    2337.0
#
#    transactions_store_lag60  transactions_store_lag90  \
# 0                    1881.0                    1346.0
# 1                    1881.0                    1346.0
# 2                    1881.0                    1346.0
# 3                    1881.0                    1346.0
# 4                    1881.0                    1346.0
#
#    transactions_store_lag120  transactions_store_lag150  \
# 0                     1685.0                     1670.0
# 1                     1685.0                     1670.0
# 2                     1685.0                     1670.0
# 3                     1685.0                     1670.0
# 4                     1685.0                     1670.0
#
#    transactions_store_lag180  transactions_store_lag210  \
# 0                      448.0                     1700.0
# 1                      448.0                     1700.0
# 2                      448.0                     1700.0
# 3                      448.0                     1700.0
# 4                      448.0                     1700.0
#
#    transactions_store_lag240  transactions_store_lag270  \
# 0                     1865.0                     1838.0
# 1                     1865.0                     1838.0
# 2                     1865.0                     1838.0
# 3                     1865.0                     1838.0
# 4                     1865.0                     1838.0
#
#    transactions_store_lag300  transactions_store_lag330  \
# 0                     1358.0                     1756.0
# 1                     1358.0                     1756.0
# 2                     1358.0                     1756.0
# 3                     1358.0                     1756.0
# 4                     1358.0                     1756.0
#
#    transactions_store_lag360  ema_transactions_store_lag_16_22  \
# 0                     1762.0                         965.07268
# 1                     1762.0                         965.07268
# 2                     1762.0                         965.07268
# 3                     1762.0                         965.07268
# 4                     1762.0                         965.07268
#
#    ema_transactions_store_lag_16_45  ema_transactions_store_lag_16_380  \
# 0                            1592.7                        1514.463014
# 1                            1592.7                        1514.463014
# 2                            1592.7                        1514.463014
# 3                            1592.7                        1514.463014
# 4                            1592.7                        1514.463014
#
#    transactions_lag16  transactions_lag17  transactions_lag18  \
# 0              1327.0            117214.0            117645.0
# 1              1327.0            117214.0            117645.0
# 2              1327.0            117214.0            117645.0
# 3              1327.0            117214.0            117645.0
# 4              1327.0            117214.0            117645.0
#
#    transactions_lag19  transactions_lag20  transactions_lag21  \
# 0             88729.0            102858.0             98330.0
# 1             88729.0            102858.0             98330.0
# 2             88729.0            102858.0             98330.0
# 3             88729.0            102858.0             98330.0
# 4             88729.0            102858.0             98330.0
#
#    transactions_lag22  transactions_lag30  transactions_lag60  \
# 0             96002.0            102356.0             76133.0
# 1             96002.0            102356.0             76133.0
# 2             96002.0            102356.0             76133.0
# 3             96002.0            102356.0             76133.0
# 4             96002.0            102356.0             76133.0
#
#    transactions_lag90  transactions_lag120  transactions_lag150  \
# 0             93205.0              67209.0              76629.0
# 1             93205.0              67209.0              76629.0
# 2             93205.0              67209.0              76629.0
# 3             93205.0              67209.0              76629.0
# 4             93205.0              67209.0              76629.0
#
#    transactions_lag180  transactions_lag210  transactions_lag240  \
# 0              80799.0              73717.0              71763.0
# 1              80799.0              73717.0              71763.0
# 2              80799.0              73717.0              71763.0
# 3              80799.0              73717.0              71763.0
# 4              80799.0              73717.0              71763.0
#
#    transactions_lag270  transactions_lag300  transactions_lag330  \
# 0              75157.0              91923.0              68246.0
# 1              75157.0              91923.0              68246.0
# 2              75157.0              91923.0              68246.0
# 3              75157.0              91923.0              68246.0
# 4              75157.0              91923.0              68246.0
#
#    transactions_lag360  ema_transactions_lag_16_22  \
# 0              68988.0                 79226.96782
# 1              68988.0                 79226.96782
# 2              68988.0                 79226.96782
# 3              68988.0                 79226.96782
# 4              68988.0                 79226.96782
#
#    ema_transactions_lag_16_45  ema_transactions_lag_16_380
# 0                92817.166667                 79747.205479
# 1                92817.166667                 79747.205479
# 2                92817.166667                 79747.205479
# 3                92817.166667                 79747.205479
# 4                92817.166667                 79747.205479
#               date  store_nbr                      family    sales  \
# 2329069 2017-08-15         54                     POULTRY   59.619
# 2329070 2017-08-15         54              PREPARED FOODS   94.000
# 2329071 2017-08-15         54                     PRODUCE  915.371
# 2329072 2017-08-15         54  SCHOOL AND OFFICE SUPPLIES    0.000
# 2329073 2017-08-15         54                     SEAFOOD    3.000
#
#          onpromotion  year  month  day  day_of_week  business_day  \
# 2329069            0  2017      8   15            1             0
# 2329070            0  2017      8   15            1             0
# 2329071           76  2017      8   15            1             0
# 2329072            0  2017      8   15            1             0
# 2329073            0  2017      8   15            1             0
#
#          sales_store_family_lag16  sales_store_family_lag17  \
# 2329069                 72.895996                    82.296
# 2329070                124.000000                    81.000
# 2329071                793.147000                   729.844
# 2329072                  0.000000                     0.000
# 2329073                  4.000000                     4.000
#
#          sales_store_family_lag18  sales_store_family_lag19  \
# 2329069                    46.656                    52.086
# 2329070                    68.000                    73.000
# 2329071                   562.097                   520.489
# 2329072                     0.000                     0.000
# 2329073                     4.000                     2.000
#
#          sales_store_family_lag20  sales_store_family_lag21  \
# 2329069                    34.856                    50.686
# 2329070                    81.000                    65.000
# 2329071                   559.658                   914.959
# 2329072                     0.000                     0.000
# 2329073                     3.000                     7.000
#
#          sales_store_family_lag22  sales_store_family_lag30  \
# 2329069                    51.209                   103.902
# 2329070                   112.000                    50.000
# 2329071                   654.930                   981.712
# 2329072                     0.000                     0.000
# 2329073                     1.000                     5.000
#
#          sales_store_family_lag60  sales_store_family_lag90  \
# 2329069                    72.770                    44.233
# 2329070                    79.000                    81.000
# 2329071                   580.389                   506.987
# 2329072                     0.000                     1.000
# 2329073                     2.000                     2.000
#
#          sales_store_family_lag120  sales_store_family_lag150  \
# 2329069                     56.169                     47.291
# 2329070                     29.000                     70.000
# 2329071                    559.538                    659.408
# 2329072                      1.000                      0.000
# 2329073                      0.000                      3.000
#
#          sales_store_family_lag180  sales_store_family_lag210  \
# 2329069                     46.572                     57.161
# 2329070                     49.000                     98.000
# 2329071                    426.046                    862.417
# 2329072                      0.000                      0.000
# 2329073                      1.000                      2.000
#
#          sales_store_family_lag240  sales_store_family_lag270  \
# 2329069                     66.212                     91.916
# 2329070                    103.000                     74.000
# 2329071                    816.129                    613.487
# 2329072                      0.000                      0.000
# 2329073                      5.000                      0.000
#
#          sales_store_family_lag300  sales_store_family_lag330  \
# 2329069                     34.801                  49.364998
# 2329070                     70.000                  80.000000
# 2329071                    555.718                 549.655000
# 2329072                      0.000                   0.000000
# 2329073                      0.000                   0.000000
#
#          sales_store_family_lag360  ema_sales_store_family_lag_16_22  \
# 2329069                     29.669                      6.453319e+01
# 2329070                     52.000                      9.153548e+01
# 2329071                    713.194                      6.889917e+02
# 2329072                      0.000                      2.320649e-09
# 2329073                      2.000                      3.621519e+00
#
#          ema_sales_store_family_lag_16_45  ema_sales_store_family_lag_16_380  \
# 2329069                         69.364066                          62.222482
# 2329070                         85.000000                          75.816438
# 2329071                        698.255533                         655.923181
# 2329072                          0.000000                           1.679452
# 2329073                          3.100000                           1.967123
#
#          sales_store_lag16  sales_store_lag17  sales_store_lag18  \
# 2329069       15815.709996          10878.746        9531.089998
# 2329070       15815.709996          10878.746        9531.089998
# 2329071       15815.709996          10878.746        9531.089998
# 2329072       15815.709996          10878.746        9531.089998
# 2329073       15815.709996          10878.746        9531.089998
#
#          sales_store_lag19  sales_store_lag20  sales_store_lag21  \
# 2329069           6911.345           6572.494           8241.906
# 2329070           6911.345           6572.494           8241.906
# 2329071           6911.345           6572.494           8241.906
# 2329072           6911.345           6572.494           8241.906
# 2329073           6911.345           6572.494           8241.906
#
#          sales_store_lag22  sales_store_lag30  sales_store_lag60  \
# 2329069       10245.246998          16959.135       10540.249999
# 2329070       10245.246998          16959.135       10540.249999
# 2329071       10245.246998          16959.135       10540.249999
# 2329072       10245.246998          16959.135       10540.249999
# 2329073       10245.246998          16959.135       10540.249999
#
#          sales_store_lag90  sales_store_lag120  sales_store_lag150  \
# 2329069          17721.085            8402.924           10604.055
# 2329070          17721.085            8402.924           10604.055
# 2329071          17721.085            8402.924           10604.055
# 2329072          17721.085            8402.924           10604.055
# 2329073          17721.085            8402.924           10604.055
#
#          sales_store_lag180  sales_store_lag210  sales_store_lag240  \
# 2329069            5518.609            7374.671           12540.281
# 2329070            5518.609            7374.671           12540.281
# 2329071            5518.609            7374.671           12540.281
# 2329072            5518.609            7374.671           12540.281
# 2329073            5518.609            7374.671           12540.281
#
#          sales_store_lag270  sales_store_lag300  sales_store_lag330  \
# 2329069         5940.149002            6340.114         8185.356998
# 2329070         5940.149002            6340.114         8185.356998
# 2329071         5940.149002            6340.114         8185.356998
# 2329072         5940.149002            6340.114         8185.356998
# 2329073         5940.149002            6340.114         8185.356998
#
#          sales_store_lag360  ema_sales_store_lag_16_22  \
# 2329069            8424.711               11041.179674
# 2329070            8424.711               11041.179674
# 2329071            8424.711               11041.179674
# 2329072            8424.711               11041.179674
# 2329073            8424.711               11041.179674
#
#          ema_sales_store_lag_16_45  ema_sales_store_lag_16_380  \
# 2329069                 10163.7067                 8816.963789
# 2329070                 10163.7067                 8816.963789
# 2329071                 10163.7067                 8816.963789
# 2329072                 10163.7067                 8816.963789
# 2329073                 10163.7067                 8816.963789
#
#          sales_family_lag16  sales_family_lag17  sales_family_lag18  \
# 2329069        25089.244942        22477.071865        28521.282225
# 2329070         5507.523005         5408.918016         4722.614983
# 2329071       146045.795000       131988.661970       111948.890000
# 2329072         2027.000000         1345.000000          567.000000
# 2329073         1379.617003         1297.514006         1307.945999
#
#          sales_family_lag19  sales_family_lag20  sales_family_lag21  \
# 2329069        14552.290992        16548.687010        16769.651937
# 2329070         4168.786016         4456.418986         4129.020989
# 2329071        90481.286100       145917.919100       115457.658700
# 2329072          244.000000          166.000000          174.000000
# 2329073          652.069999          839.655002          842.090999
#
#          sales_family_lag22  sales_family_lag30  sales_family_lag60  \
# 2329069        19464.661030        26360.768010        31804.989046
# 2329070         4823.321997         5534.052983         5001.446010
# 2329071       117117.095010       157883.056000       124173.953500
# 2329072          192.000000          121.000000           58.000000
# 2329073          995.327001         1413.877000         1315.639001
#
#          sales_family_lag90  sales_family_lag120  sales_family_lag150  \
# 2329069         18491.03000         17711.450004         23457.777090
# 2329070          4738.09202          4342.841024          7189.561030
# 2329071        166802.77490        115072.020880        139267.040030
# 2329072           215.00000           718.000000           150.000000
# 2329073          1195.40500           998.932001          1597.305998
#
#          sales_family_lag180  sales_family_lag210  sales_family_lag240  \
# 2329069         16029.954000         17694.390035         26878.779050
# 2329070          5153.443006          5341.388989          7448.360985
# 2329071         95892.378030        124250.204900        155663.954600
# 2329072            60.000000            80.000000           129.000000
# 2329073           858.070005           990.695003          1289.671995
#
#          sales_family_lag270  sales_family_lag300  sales_family_lag330  \
# 2329069         28038.540014         15365.961035         16143.457978
# 2329070          5268.237992          4946.688980          5305.362987
# 2329071        102969.517830        138579.652000        104423.301000
# 2329072            71.000000            69.000000           146.000000
# 2329073          1362.009002          1080.609002          1138.018999
#
#          sales_family_lag360  ema_sales_family_lag_16_22  \
# 2329069         21158.702034                22225.768154
# 2329070          6106.435004                 4968.954790
# 2329071        120558.737800               127348.465736
# 2329072           787.000000                  925.102321
# 2329073          1447.197998                 1155.706294
#
#          ema_sales_family_lag_16_45  ema_sales_family_lag_16_380  dcoilwtico  \
# 2329069                21734.075462                 21059.267403       47.57
# 2329070                 4894.940064                  5550.034376       47.57
# 2329071               129450.195936                125742.800885       47.57
# 2329072                  239.033333                   300.334247       47.57
# 2329073                 1131.143900                  1213.799340       47.57
#
#          dcoilwtico_lag1  dcoilwtico_lag2  dcoilwtico_lag3  dcoilwtico_lag4  \
# 2329069            47.59            48.81            48.81            48.81
# 2329070            47.59            48.81            48.81            48.81
# 2329071            47.59            48.81            48.81            48.81
# 2329072            47.59            48.81            48.81            48.81
# 2329073            47.59            48.81            48.81            48.81
#
#          dcoilwtico_lag5  dcoilwtico_lag6  dcoilwtico_lag7  \
# 2329069            48.54            49.59            49.07
# 2329070            48.54            49.59            49.07
# 2329071            48.54            49.59            49.07
# 2329072            48.54            49.59            49.07
# 2329073            48.54            49.59            49.07
#
#          ema_dcoilwtico_lag_1_7  ema_dcoilwtico_lag_1_30  \
# 2329069                48.62108                   48.274
# 2329070                48.62108                   48.274
# 2329071                48.62108                   48.274
# 2329072                48.62108                   48.274
# 2329073                48.62108                   48.274
#
#          ema_dcoilwtico_lag_1_365       city   state type  cluster  \
# 2329069                    48.274  El Carmen  Manabi    C        3
# 2329070                    48.274  El Carmen  Manabi    C        3
# 2329071                    48.274  El Carmen  Manabi    C        3
# 2329072                    48.274  El Carmen  Manabi    C        3
# 2329073                    48.274  El Carmen  Manabi    C        3
#
#          national_holiday  national_event  local_holiday  regional_holiday  \
# 2329069                 0               0              0                 0
# 2329070                 0               0              0                 0
# 2329071                 0               0              0                 0
# 2329072                 0               0              0                 0
# 2329073                 0               0              0                 0
#
#          transactions_store_lag16  transactions_store_lag17  \
# 2329069                    1108.0                     870.0
# 2329070                    1108.0                     870.0
# 2329071                    1108.0                     870.0
# 2329072                    1108.0                     870.0
# 2329073                    1108.0                     870.0
#
#          transactions_store_lag18  transactions_store_lag19  \
# 2329069                     766.0                     662.0
# 2329070                     766.0                     662.0
# 2329071                     766.0                     662.0
# 2329072                     766.0                     662.0
# 2329073                     766.0                     662.0
#
#          transactions_store_lag20  transactions_store_lag21  \
# 2329069                     700.0                     727.0
# 2329070                     700.0                     727.0
# 2329071                     700.0                     727.0
# 2329072                     700.0                     727.0
# 2329073                     700.0                     727.0
#
#          transactions_store_lag22  transactions_store_lag30  \
# 2329069                     792.0                     920.0
# 2329070                     792.0                     920.0
# 2329071                     792.0                     920.0
# 2329072                     792.0                     920.0
# 2329073                     792.0                     920.0
#
#          transactions_store_lag60  transactions_store_lag90  \
# 2329069                     754.0                     706.0
# 2329070                     754.0                     706.0
# 2329071                     754.0                     706.0
# 2329072                     754.0                     706.0
# 2329073                     754.0                     706.0
#
#          transactions_store_lag120  transactions_store_lag150  \
# 2329069                      724.0                      968.0
# 2329070                      724.0                      968.0
# 2329071                      724.0                      968.0
# 2329072                      724.0                      968.0
# 2329073                      724.0                      968.0
#
#          transactions_store_lag180  transactions_store_lag210  \
# 2329069                      662.0                      745.0
# 2329070                      662.0                      745.0
# 2329071                      662.0                      745.0
# 2329072                      662.0                      745.0
# 2329073                      662.0                      745.0
#
#          transactions_store_lag240  transactions_store_lag270  \
# 2329069                     1165.0                      714.0
# 2329070                     1165.0                      714.0
# 2329071                     1165.0                      714.0
# 2329072                     1165.0                      714.0
# 2329073                     1165.0                      714.0
#
#          transactions_store_lag300  transactions_store_lag330  \
# 2329069                      678.0                      847.0
# 2329070                      678.0                      847.0
# 2329071                      678.0                      847.0
# 2329072                      678.0                      847.0
# 2329073                      678.0                      847.0
#
#          transactions_store_lag360  ema_transactions_store_lag_16_22  \
# 2329069                      916.0                        858.501135
# 2329070                      916.0                        858.501135
# 2329071                      916.0                        858.501135
# 2329072                      916.0                        858.501135
# 2329073                      916.0                        858.501135
#
#          ema_transactions_store_lag_16_45  ema_transactions_store_lag_16_380  \
# 2329069                        807.233333                         830.684932
# 2329070                        807.233333                         830.684932
# 2329071                        807.233333                         830.684932
# 2329072                        807.233333                         830.684932
# 2329073                        807.233333                         830.684932
#
#          transactions_lag16  transactions_lag17  transactions_lag18  \
# 2329069             94899.0            100227.0             89197.0
# 2329070             94899.0            100227.0             89197.0
# 2329071             94899.0            100227.0             89197.0
# 2329072             94899.0            100227.0             89197.0
# 2329073             94899.0            100227.0             89197.0
#
#          transactions_lag19  transactions_lag20  transactions_lag21  \
# 2329069             78743.0             82113.0             81930.0
# 2329070             78743.0             82113.0             81930.0
# 2329071             78743.0             82113.0             81930.0
# 2329072             78743.0             82113.0             81930.0
# 2329073             78743.0             82113.0             81930.0
#
#          transactions_lag22  transactions_lag30  transactions_lag60  \
# 2329069             85120.0             96119.0             92852.0
# 2329070             85120.0             96119.0             92852.0
# 2329071             85120.0             96119.0             92852.0
# 2329072             85120.0             96119.0             92852.0
# 2329073             85120.0             96119.0             92852.0
#
#          transactions_lag90  transactions_lag120  transactions_lag150  \
# 2329069             85560.0              83043.0              99094.0
# 2329070             85560.0              83043.0              99094.0
# 2329071             85560.0              83043.0              99094.0
# 2329072             85560.0              83043.0              99094.0
# 2329073             85560.0              83043.0              99094.0
#
#          transactions_lag180  transactions_lag210  transactions_lag240  \
# 2329069              77887.0              80093.0             116289.0
# 2329070              77887.0              80093.0             116289.0
# 2329071              77887.0              80093.0             116289.0
# 2329072              77887.0              80093.0             116289.0
# 2329073              77887.0              80093.0             116289.0
#
#          transactions_lag270  transactions_lag300  transactions_lag330  \
# 2329069              81854.0              72931.0              76255.0
# 2329070              81854.0              72931.0              76255.0
# 2329071              81854.0              72931.0              76255.0
# 2329072              81854.0              72931.0              76255.0
# 2329073              81854.0              72931.0              76255.0
#
#          transactions_lag360  ema_transactions_lag_16_22  \
# 2329069              91798.0                90578.055207
# 2329070              91798.0                90578.055207
# 2329071              91798.0                90578.055207
# 2329072              91798.0                90578.055207
# 2329073              91798.0                90578.055207
#
#          ema_transactions_lag_16_45  ema_transactions_lag_16_380
# 2329069                89847.766667                 87374.260274
# 2329070                89847.766667                 87374.260274
# 2329071                89847.766667                 87374.260274
# 2329072                89847.766667                 87374.260274
# 2329073                89847.766667                 87374.260274

# %%
df.to_parquet('data/modelling.parquet', index=False)
